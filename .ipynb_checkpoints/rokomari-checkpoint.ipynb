# %%
from bs4 import BeautifulSoup
import requests
import time
from datetime import datetime
from urllib.parse import urljoin
from openpyxl import Workbook
import pytz

# %%
bst = pytz.timezone('Asia/Dhaka')

#create a new Workbook
wb = Workbook()
#create a new worksheet
ws = wb.active
#add headers to the first row of the worksheet
headers = ["Date", "Time","Book Title", "Author", "Category", "Original Price", "Sell Price", "Discount", "Best Seller Merit", "E-book Availability", "E-book Price", "Ratings Count",
           "Reviews Count", "Rating", "Publisher", "Language", "Country"]
ws.append(headers)

# %%
total_page = 166
page_number = 101
while page_number <= total_page:
    
    print(f"---------------data is loading from {page_number}---------\n\n")
    #make connection with website
    url = 'https://www.rokomari.com/search?term=book&search_type=BOOK&page='+ str(page_number)
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}
    page = requests.get(url,headers=headers)   
    soup_1 = BeautifulSoup(page.content,"html.parser")  
    soup_2 = BeautifulSoup(soup_1.prettify(),"html.parser")    
    books_div_area = soup_2.find_all("div",class_='book-list-wrapper')   
    book_links = [elem.find("a").get('href') for elem in books_div_area]

    
    for link in book_links:
        
        full_link = urljoin(url, link)  # Concatenating the base URL with the link
        book_page = requests.get(full_link, headers=headers)
        book_soup = BeautifulSoup(book_page.content, "html.parser")
        book_soup_prettify = BeautifulSoup(book_soup.prettify(),"html.parser")
        #pillar
        main_header_1 = book_soup_prettify.find("div",class_="col details-book-main-info align-self-center")
        main_header_2 = book_soup_prettify.find("div",class_="details-stationary__details h-100")
        books_header_1 = book_soup_prettify.find("div", class_="details-book-main-info__header") 
        books_header_2 = book_soup_prettify.find("div",class_="details-stationary__details h-100")
        additional_info_1 = book_soup_prettify.find("div",id="book-additional-specification")
        additional_info_2 = book_soup_prettify.find("table",class_="specification-section__table border-top pt-3 mt-4")      
        #initialize variables
        book_title = book_author = category = original_price = sell_price = discount = best_seller_merit = ebook_availability = ebook_price = ratings_count = reviews_count = rating = publisher_name = country_name = language_name = ""
    
        if main_header_1 and books_header_1: 
            
            current_date = datetime.now().date()
            current_time = datetime.now(bst)
            current_time = current_time.strftime('%I:%M:%S %p')

            #book title
            try:
                title = books_header_1.find("h1")
                book_title = title.contents[0].strip()
            except AttributeError:
                book_title = ""
                pass
            #book author name
            try:
                book_author = main_header_1.find("p",class_="details-book-info__content-author").find("a").text.strip()
            except AttributeError:
                book_author = ""
                pass
            #category name
            try:
                category = main_header_1.find("div",class_="details-book-info__content-category d-flex align-items-center").find("a").text.strip()
            except AttributeError:
                category = ""
                pass
            #original price
            try:
                original_price_div = main_header_1.find("div", class_="details-book-info__content-book-price")
                if original_price_div and original_price_div.find("strike"):
                    #original price exists, so extract the text
                    original_price = original_price_div.find("strike").text.strip()
                else:
                    #original price does not exist
                    original_price = ""  #or set it to some default value
            except  AttributeError:
                original_price = ""
                pass
            #sell price
            try:
                sell_price = main_header_1.find("span",class_="sell-price").text.strip()
            except AttributeError:
                sell_price = ""
                pass
            #discount amount
            try:
                discount_div = main_header_1.find("div", class_="details-book-info__content-book-price")
                if discount_div and discount_div.find("span",class_="js--save-message"):
                    discount = discount_div.find(class_="js--save-message").text.strip()
                else:
                    discount = ""  #or set it to some default value
            except AttributeError:
                discount = ""
                pass
            #best selller badge
            try:
                best_seller_merit_div = main_header_1.find("p",class_="best-seller-badge")
                if best_seller_merit_div:
                    best_seller_merit = best_seller_merit_div.find("span").text.strip()
                else:
                    best_seller_merit = ""
                    
            except AttributeError:
                best_seller_merit = ""
                pass        
            #ebook availability
            try:
                ebook_availability_ensure = main_header_1.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_availability = "Yes"
                else:
                    ebook_availability = "No"
            except AttributeError:
                ebook_availability = "No"
                pass
            #ebook price
            try:
                ebook_availability_ensure = main_header_1.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_price = ebook_availability_ensure.find("p",class_="ebook-price").text.strip()
                else:
                    ebook_price = ""
            except AttributeError:
                ebook_price = ""
                pass   
            #ratings count
            try:
                ratings_reviwe = main_header_1.find("div", class_="details-book-info__content-rating").find("span", "ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                # Extract ratings count
                ratings_count = ratings_text.strip().split()[0]
            except AttributeError:
                ratings_count = ""
                pass
            #reviews count
            try:
                ratings_reviwe = main_header_1.find("div", class_="details-book-info__content-rating").find("span", "ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                reviews_count = reviews_text.strip().split()[0]
            except AttributeError:
                reviews_count = ""
                pass
            #ratings
            try:
                rating = book_soup_prettify.find("div",class_="review-wrapper__rating-summary").find("h3",class_="summary-title").text.strip()
            except AttributeError:
                rating = ""
                pass        
            #publisher name
            try:          
                publisher_name_info = additional_info_1.find("table",class_="table table-bordered")
                if publisher_name_info and publisher_name_info.find("td",class_="publisher-link").find("a"):
                    publisher_name = publisher_name_info.find("td",class_="publisher-link").find("a").text.strip()
                else:
                    publisher_name = ""
            except AttributeError:
                publisher_name = ""
            #country name
            try:
                country_name_infos = additional_info_1.find_all("td")
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Country":
                        c_name = country_name_info.find_next_sibling("td")
                        country_name = c_name.get_text(strip=True)
                        break
                    else:
                        country_name = ""
                        continue
            except AttributeError:
                country_name = ""
                pass
            #language information
            try:
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Language":
                        l_name = country_name_info.find_next_sibling("td")
                        language_name = l_name.get_text(strip=True)
                        break
                    else:
                        language_name = ""
                        continue
            except AttributeError:
                language_name = ""
                pass
            #add the extracted data to the worksheet
            row_data = [current_date, current_time, book_title, book_author, category, original_price, sell_price, discount, best_seller_merit, ebook_availability, ebook_price, ratings_count,
                        reviews_count, rating, publisher_name, language_name, country_name]
            ws.append(row_data)
               
            print(f"Information of {book_title}: {page_number}\n\n")
            print("Current Date:", current_date)
            print("Current Time:", current_time)
            print(f"Book Title:{book_title}")
            print(f"Book Author Name:{book_author}")
            print(f"Book Catagory:{category}")
            print(f"Original Price:{original_price} tk")
            print(f"Sell Price:{sell_price} tk")
            print(f"Discount Rate:{discount}")
            print(f"Best seller merit:{best_seller_merit}")
            print(f"E-book availability:{ebook_availability}")
            print(f"E-book price:{ebook_price}")
            print(f"Total Ratings:{ratings_count}")
            print(f"Total Review:{reviews_count}")
            print(f"Ratings:{rating}")
            print(f"Publication name:{publisher_name}")
            print(f"Language:{language_name}")
            print(f"Country name:{country_name}")
            print(f"-----------------\n\n") 
            
        elif main_header_2 and books_header_2:

            current_date = datetime.now().date()
            current_time = datetime.now(bst)
            current_time = current_time.strftime('%I:%M:%S %p')
            
            #book name
            try:
                title = books_header_2.find("h1", class_="title mb-0")
                book_title = title.contents[0].strip()
            except AttributeError:
                book_title = ""
                pass          
            #author name
            try:
                book_author = main_header_2.find("p", class_="details-stationary__brand").find("a").text.strip()
            except AttributeError:
                book_author = ""
                pass     
            #category name
            try:
                category = main_header_2.find("p", class_="details-stationary__category").find("a").text.strip()
            except AttributeError:
                category = ""
                pass            
            #original price
            try:
                original_price_div = main_header_2.find("div", class_="details-stationary__price")
                if original_price_div and original_price_div.find("strike"):
                    original_price = original_price_div.find("strike").text.strip()
                else:
                    original_price = ""
            except AttributeError:
                original_price = ""
                pass            
            #sell price
            try:
                sell_price = main_header_2.find("span", class_="sell-price").text.strip()
            except AttributeError:
                sell_price = ""
                pass           
            #discount rate
            try:
                discount_div = main_header_2.find("div", class_="details-stationary__price")
                if discount_div and discount_div.find("span", class_="js--save-message"):
                    discount = discount_div.find(class_="js--save-message").text.strip()
                else:
                    discount = ""
            except AttributeError:
                discount = ""
                pass

            #best selller badge
            try:
                best_seller_merit_div = main_header_2.find("p",class_="best-seller-badge")
                if best_seller_merit_div:
                    best_seller_merit = best_seller_merit_div.find("span").text.strip()
                else:
                    best_seller_merit = ""
                    
            except AttributeError:
                best_seller_merit = ""
                pass
            #ebook availability
            try:
                ebook_availability_ensure = main_header_2.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_availability = "Yes"
                else:
                    ebook_availability = "No"
            except AttributeError:
                ebook_availability = "No"
                pass
            #ebook price
            try:
                ebook_availability_ensure = main_header_2.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_price = ebook_availability_ensure.find("p",class_="ebook-price").text.strip()
                else:
                    ebook_price = ""
            except AttributeError:
                ebook_price = ""
                pass          
            #rating count
            try:
                ratings_reviwe = main_header_2.find("div", class_="details-stationary__stars").find("span", class_="ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                # Extract ratings count
                ratings_count = ratings_text.strip().split()[0]
            except AttributeError:
                ratings_count = ""
                pass
            #reviews count
            try:
                ratings_reviwe = main_header_2.find("div", class_="details-stationary__stars").find("span", class_="ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                reviews_count = reviews_text.strip().split()[0]
            except AttributeError:
                reviews_count = ""
                pass

            #ratings
            try:
                rating = book_soup_prettify.find("div",class_="details-ratings-review__rating-summary").find("h3",class_="summary-title").text.strip()
            except AttributeError:
                rating = ""
                pass
            #publisher name
            try:
                publisher_infos = additional_info_2.find_all("td", class_="proDetailValue")
                for publisher_info in publisher_infos:
                    if publisher_info.find("a"):
                        publisher_name = publisher_info.find("a").text.strip()
                        break
                else:
                    publisher_name = ""
            except AttributeError:
                publisher_name = ""
                pass          
            #country name
            try:
                country_name_infos = additional_info_2.find_all("td")
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() ==  "Country of Origin":
                        c_name = country_name_info.find_next_sibling("td")
                        country_name = c_name.get_text(strip=True)
                        break
                else:
                    country_name = ""
            except AttributeError:
                country_name = ""
                pass          
            #language name
            try:
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Version":
                        l_name = country_name_info.find_next_sibling("td")
                        language_name = l_name.get_text(strip=True)
                        break
                else:
                    language_name = ""
            except AttributeError:
                language_name = ""
                pass

            #add the extracted data to the worksheet
            row_data = [current_date, current_time, book_title, book_author, category, original_price, sell_price, discount, best_seller_merit, ebook_availability, ebook_price, ratings_count,
                        reviews_count, rating, publisher_name, language_name, country_name]
            ws.append(row_data)
            
            print(f"Information of {book_title}: {page_number}\n\n")
            print("Current Date:", current_date)
            print("Current Time:", current_time)
            print(f"Book Title:{book_title}")
            print(f"Book Author Name:{book_author}")
            print(f"Book Catagory:{category}")
            print(f"Original Price:{original_price} tk")
            print(f"Sell Price:{sell_price} tk")
            print(f"Discount Rate:{discount}")
            print(f"Best seller merit:{best_seller_merit}")
            print(f"E-book availability:{ebook_availability}")
            print(f"E-book price:{ebook_price}")
            print(f"Total Ratings:{ratings_count}")
            print(f"Total Review:{reviews_count}")
            print(f"Ratings:{rating}")
            print(f"Publication name:{publisher_name}")
            print(f"Language:{language_name}")
            print(f"Country name:{country_name}")
            print("-----------------\n\n")
        else:
            print("Book title not found for:", full_link)

    print(f"\n\n---------------data is loaded of {page_number}---------\n\n")
    page_number = page_number + 1
    
#save the workbook
wb.save("C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_books_informations2.xlsx")
print(f"Total loaded page {page_number}")
# Out:
# ---------------data is loading from 101---------
#
#
# Information of এক অলৌকিক ঘটনা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:44 PM
# Book Title:এক অলৌকিক ঘটনা
# Book Author Name:সানিয়াসনাইন খান
# Book Catagory:When 8-12: Religious Books
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:2
# Ratings:5.0
# Publication name:Banglaprokash
# Language:Bangla & English
# Country name:Bangladesh
# -----------------
#
#
# Information of নজরুলের শিশু কিশোর সাহিত্য: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:46 PM
# Book Title:নজরুলের শিশু কিশোর সাহিত্য
# Book Author Name:কাজী নজরুল ইসলাম
# Book Catagory:শিশু-কিশোর সাহিত্য/রচনা সমগ্র
# Original Price: tk
# Sell Price:TK. 400 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:5.0
# Publication name:নজরুল ইন্সটিটিউট
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দেশবিদেশ ভ্রমন: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:48 PM
# Book Title:দেশবিদেশ ভ্রমন
# Book Author Name:জগদীশ চন্দ্র বসু
# Book Catagory:ভ্রমণ ও প্রবাস: ক্লাসিক
# Original Price:TK. 150 tk
# Sell Price:TK. 113 tk
# Discount Rate:You Save TK. 37 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:পাঞ্জেরী পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য ফাইভ সেকেন্ড রুল: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:49 PM
# Book Title:দ্য ফাইভ সেকেন্ড রুল
# Book Author Name:মেল রবিন্স
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 300 tk
# Sell Price:TK. 258 tk
# Discount Rate:You Save TK. 42 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 81
# Total Ratings:4
# Total Review:5
# Ratings:4.0
# Publication name:প্রিয়মুখ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বুড়িমা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:51 PM
# Book Title:বুড়িমা
# Book Author Name:সব্যসাচী মিস্ত্রী
# Book Catagory:বয়স যখন ৮-১২: কমিকস ও ছবির গল্প
# Original Price:TK. 80 tk
# Sell Price:TK. 69 tk
# Discount Rate:You Save TK. 11 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:ময়ূরপঙ্খি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের জ্ঞানকোষ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:53 PM
# Book Title:ছোটদের জ্ঞানকোষ
# Book Author Name:সিকদার আবুল বাশার
# Book Catagory:ছোটদের গণিত, বিজ্ঞান ও প্রযুক্তি
# Original Price:TK. 120 tk
# Sell Price:TK. 103 tk
# Discount Rate:You Save TK. 17 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:কাকলী প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের রাগ অঞ্জলি (সঙ্গীত শিক্ষা :প্রথম পাঠ): 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:56 PM
# Book Title:ছোটদের রাগ অঞ্জলি (সঙ্গীত শিক্ষা :প্রথম পাঠ)
# Book Author Name:শঙ্কর রায়
# Book Catagory:স্বরলিপি
# Original Price:TK. 220 tk
# Sell Price:TK. 189 tk
# Discount Rate:You Save TK. 31 (14%)
# Best seller merit:#6 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:4.0
# Publication name:কাকলী প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ব্যাপন কিশোর বিজ্ঞান সাময়িকী (মে-জুন ২০২৩): 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:21:58 PM
# Book Title:ব্যাপন কিশোর বিজ্ঞান সাময়িকী (মে-জুন ২০২৩)
# Book Author Name:ড. মোঃ শামসুল আরিফিন জিলানী
# Book Catagory:বিজ্ঞান ম্যাগাজিন: বিশেষ সংস্করণ
# Original Price:TK. 40 tk
# Sell Price:TK. 30 tk
# Discount Rate:You Save TK. 10 (25%)
# Best seller merit:#2 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:15
# Total Review:14
# Ratings:5.0
# Publication name:ব্যাপন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ১৯৭১ বিধ্বস্ত বাড়িয়ায় শুধুই লাশ এবং: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:02 PM
# Book Title:১৯৭১ বিধ্বস্ত বাড়িয়ায় শুধুই লাশ এবং
# Book Author Name:ইজাজ আহমেদ মিলন
# Book Catagory:যুদ্ধাপরাধ, গণহত্যা, শরণার্থী, নারী ও শিশু
# Original Price:TK. 450 tk
# Sell Price:TK. 387 tk
# Discount Rate:You Save TK. 63 (14%)
# Best seller merit:#8 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:অন্যপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বাংলাদেশ : রাষ্ট্র ও রাজনীতি: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:06 PM
# Book Title:বাংলাদেশ : রাষ্ট্র ও রাজনীতি
# Book Author Name:ড. তারেক শামসুর রেহমান (সম্পাদক)
# Book Catagory:রাজনৈতিক গবেষণা ও প্রবন্ধ
# Original Price:TK. 450 tk
# Sell Price:TK. 387 tk
# Discount Rate:You Save TK. 63 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 122
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:শোভা প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of রংধনুপরি ও জাদুকর: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:08 PM
# Book Title:রংধনুপরি ও জাদুকর
# Book Author Name:সালমা কিবরিয়া
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:3
# Ratings:5.0
# Publication name:প্রতিভা প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ডাঁটি ভাঙা চশমা রাফিদ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:10 PM
# Book Title:ডাঁটি ভাঙা চশমা রাফিদ
# Book Author Name:সুমন্ত আসলাম
# Book Catagory:শিশু-কিশোর উপন্যাস
# Original Price:TK. 160 tk
# Sell Price:TK. 138 tk
# Discount Rate:You Save TK. 22 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:5.0
# Publication name:কাকলী প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ব্ল্যাক বিউটি: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:12 PM
# Book Title:ব্ল্যাক বিউটি
# Book Author Name:আনা সোয়েল
# Book Catagory:বয়স যখন ৮-১২: গল্প
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:5
# Ratings:5.0
# Publication name:পাঞ্জেরী পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of মজার পড়া ১০০ ছড়া: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:14 PM
# Book Title:মজার পড়া ১০০ ছড়া
# Book Author Name:সুকুমার বড়ুয়া
# Book Catagory:ছড়া
# Original Price:TK. 210 tk
# Sell Price:TK. 181 tk
# Discount Rate:You Save TK. 29 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:অ্যাডর্ন পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বিবাহের ব্যবস্থা করুন...: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:15 PM
# Book Title:বিবাহের ব্যবস্থা করুন...
# Book Author Name:মুস্তাফিজ ইবনে আনির
# Book Catagory:ইসলামি বিধি-বিধান ও মাসআলা-মাসায়েল
# Original Price:TK. 165 tk
# Sell Price:TK. 116 tk
# Discount Rate:You Save TK. 49 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:3
# Ratings:5.0
# Publication name:আলোর ঠিকানা প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of সবজি ভাসে ভেলায়: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:17 PM
# Book Title:সবজি ভাসে ভেলায়
# Book Author Name:সিসিমপুর (সম্পাদক)
# Book Catagory:বয়স যখন ৪-৮: কমিক্স ও ছবির গল্প
# Original Price:TK. 200 tk
# Sell Price:TK. 172 tk
# Discount Rate:You Save TK. 28 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:সিসিমপুর
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of চাচা চৌধুরী ফুটবল ওয়ার্ল্ড কাপ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:18 PM
# Book Title:চাচা চৌধুরী ফুটবল ওয়ার্ল্ড কাপ
# Book Author Name:প্রাণ
# Book Catagory:পশ্চিমবঙ্গের বই: কমিকস ও ছবির গল্প
# Original Price:TK. 180 tk
# Sell Price:TK. 162 tk
# Discount Rate:You Save TK. 18 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:No
# Ratings:5.0
# Publication name:ডায়মন্ড টুনস (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of সময় রেখায় বঙ্গবন্ধু সে আগুন ছড়িয়ে গেলো সবখানে (ট্রাভেলার্স বুক- হার্ড কাভার): 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:21 PM
# Book Title:সময় রেখায় বঙ্গবন্ধু সে আগুন ছড়িয়ে গেলো সবখানে (ট্রাভেলার্স বুক- হার্ড কাভার)
# Book Author Name:এন আই খান
# Book Catagory:রাজনীতি ও রাজনীতিবিদ বিষয়ক প্রবন্ধ
# Original Price:TK. 960 tk
# Sell Price:TK. 922 tk
# Discount Rate:You Save TK. 38 (4%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:শিলালিপি (ঢাকা)
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের আখলাক সিরিজ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:22 PM
# Book Title:ছোটদের আখলাক সিরিজ
# Book Author Name:শাবান মুস্তফা কাযামিল
# Book Catagory:শিশু-কিশোর ইসলামি বই
# Original Price:TK. 300 tk
# Sell Price:TK. 180 tk
# Discount Rate:You Save TK. 120 (40%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 36
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:মাকতাবাতুল ফুরকান
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of স্বর্ণবাজ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:24 PM
# Book Title:স্বর্ণবাজ
# Book Author Name:সিদ্দিক আহমেদ
# Book Catagory:ঐতিহাসিক উপন্যাস
# Original Price:TK. 500 tk
# Sell Price:TK. 415 tk
# Discount Rate:You Save TK. 85 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:5.0
# Publication name:ঋদ্ধ প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কুরআন পড়বেন কেন? কিভাবে?: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:27 PM
# Book Title:কুরআন পড়বেন কেন? কিভাবে?
# Book Author Name:মাওলানা আবদুস শহীদ নাসিম
# Book Catagory:কুরআন বিষয়ক আলোচনা
# Original Price:TK. 270 tk
# Sell Price:TK. 189 tk
# Discount Rate:You Save TK. 81 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:5.0
# Publication name:বর্ণালি বুক সেন্টার-বিবিসি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of অনলশিখায় কি করিনু খেলা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:29 PM
# Book Title:অনলশিখায় কি করিনু খেলা
# Book Author Name:দেবদাস ভট্টাচার্য
# Book Catagory:সমকালীন উপন্যাস
# Original Price:TK. 340 tk
# Sell Price:TK. 255 tk
# Discount Rate:You Save TK. 85 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:No
# Total Review:1
# Ratings:
# Publication name:তাম্রলিপি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of হায়াতুস্‌ সাহাবা (সকল খণ্ড একত্রে): 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:30 PM
# Book Title:হায়াতুস্‌ সাহাবা (সকল খণ্ড একত্রে)
# Book Author Name:হযরত মাওলানা মুহাম্মদ ইউসুফ কান্ধলভী রহ.
# Book Catagory:নবি-রাসুল, সাহাবা, তাবেই ও অলি-আওলিয়া
# Original Price:TK. 1,400 tk
# Sell Price:TK. 770 tk
# Discount Rate:You Save TK. 630 (45%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:2
# Ratings:4.67
# Publication name:সোলেমানিয়া বুক হাউস
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গুনিয়াতুত্ ত্বালেবীন -১ম ও ২য় খণ্ড: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:33 PM
# Book Title:গুনিয়াতুত্ ত্বালেবীন -১ম ও ২য় খণ্ড
# Book Author Name:হযরত আব্দুল কাদের জিলানী (রহঃ)
# Book Catagory:ইসলামি অনুবাদ বই
# Original Price:TK. 600 tk
# Sell Price:TK. 420 tk
# Discount Rate:You Save TK. 180 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:রশীদ বুক হাউজ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of লাইফ অ্যান্ড ড্রিমস্ অব টিপু সুলতান: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:36 PM
# Book Title:লাইফ অ্যান্ড ড্রিমস্ অব টিপু সুলতান
# Book Author Name:হেলাল হামাম
# Book Catagory:ঐতিহাসিক ব্যক্তিত্ব
# Original Price:TK. 210 tk
# Sell Price:TK. 180 tk
# Discount Rate:You Save TK. 30 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 57
# Total Ratings:6
# Total Review:5
# Ratings:5.0
# Publication name:ঐতিহ্য
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দু‘আ-যিকর, ওয়াসীলাহ-শাফায়াত: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:37 PM
# Book Title:দু‘আ-যিকর, ওয়াসীলাহ-শাফায়াত
# Book Author Name:ড. মোহাম্মদ ইমাম হোসাইন
# Book Catagory:Dua, Dorud and Zikr
# Original Price:TK. 170 tk
# Sell Price:TK. 119 tk
# Discount Rate:You Save TK. 51 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:5.0
# Publication name:Sobujpatro Publications
# Language:Bangla & Arabic
# Country name:Bangladesh
# -----------------
#
#
# Information of ইসলাম ও জ্ঞান: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:39 PM
# Book Title:ইসলাম ও জ্ঞান
# Book Author Name:প্রফেসর ড. নাজমুদ্দিন এরবাকান
# Book Catagory:ইসলাম ধর্মীয় ব্যক্তিত্ব
# Original Price:TK. 35 tk
# Sell Price:TK. 25 tk
# Discount Rate:You Save TK. 10 (29%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:14
# Total Review:10
# Ratings:4.43
# Publication name:মক্তব প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আত্মকথা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:41 PM
# Book Title:আত্মকথা
# Book Author Name:জি অ্যালানা
# Book Catagory:বঙ্গবন্ধু শেখ মুজিবুর রহমান
# Original Price:TK. 350 tk
# Sell Price:TK. 313 tk
# Discount Rate:You Save TK. 37 (11%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:1.0
# Publication name:মাতৃভূমি প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of উভচর মানুষ: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:42 PM
# Book Title:উভচর মানুষ
# Book Author Name:আলেক্সান্দার বেলায়েভ
# Book Catagory:অনুবাদ গল্প
# Original Price:TK. 250 tk
# Sell Price:TK. 215 tk
# Discount Rate:You Save TK. 35 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:6
# Total Review:3
# Ratings:4.67
# Publication name:অবসর প্রকাশনা সংস্থা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আপনজনদের বেইমানিতে পতন সিরাজউদ্দৌলার: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:44 PM
# Book Title:আপনজনদের বেইমানিতে পতন সিরাজউদ্দৌলার
# Book Author Name:নঈম নিজাম
# Book Catagory:প্রবন্ধ: কলাম সংগ্রহ/সংকলন
# Original Price:TK. 470 tk
# Sell Price:TK. 353 tk
# Discount Rate:You Save TK. 117 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:3
# Ratings:2.33
# Publication name:অন্বেষা প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of যুবকদের জন্য সালাফদের নসীহা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:45 PM
# Book Title:যুবকদের জন্য সালাফদের নসীহা
# Book Author Name:শায়খ আব্দুর রাজ্জাক ইবন আব্দুল মুহসিন আল বদর
# Book Catagory:ইসলামি বিধি-বিধান ও মাসআলা-মাসায়েল
# Original Price:TK. 25 tk
# Sell Price:TK. 20 tk
# Discount Rate:You Save TK. 5 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:5.0
# Publication name:ওয়াহীদিয়া ইসলামিয়া লাইব্রেরী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of যুদ্ধোত্তর থেকে করোনাকাল: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:47 PM
# Book Title:যুদ্ধোত্তর থেকে করোনাকাল
# Book Author Name:রাশেদ আল মাহমুদ তিতুমীর
# Book Catagory:ইতিহাস ও ঐতিহ্য: গবেষণা ও প্রবন্ধ
# Original Price:TK. 480 tk
# Sell Price:TK. 430 tk
# Discount Rate:You Save TK. 50 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:No
# Total Review:1
# Ratings:
# Publication name:প্রথমা প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কবরের আযাব: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:49 PM
# Book Title:কবরের আযাব
# Book Author Name:আল্লামা তারিক জামিল
# Book Catagory:মৃত্যু, পরকাল ও জান্নাত-জাহান্নাম
# Original Price:TK. 230 tk
# Sell Price:TK. 127 tk
# Discount Rate:You Save TK. 103 (45%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:1.0
# Publication name:মাকতাবাতুত তাসনীম
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দিন শেষে: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:51 PM
# Book Title:দিন শেষে
# Book Author Name:রবিন জামান খান
# Book Catagory:রহস্য ও গোয়েন্দা
# Original Price:TK. 240 tk
# Sell Price:TK. 206 tk
# Discount Rate:You Save TK. 34 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:3
# Ratings:2.75
# Publication name:অন্যধারা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of SEO এবং অনলাইনে জীবন বদলের গল্প: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:53 PM
# Book Title:SEO এবং অনলাইনে জীবন বদলের গল্প
# Book Author Name:নাসির উদ্দিন শামীম
# Book Catagory:ফ্রিল্যান্সিং ও আউটসোর্সিং
# Original Price:TK. 500 tk
# Sell Price:TK. 375 tk
# Discount Rate:You Save TK. 125 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:5.0
# Publication name:অদম্য প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ঈমানী গল্প-২: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:55 PM
# Book Title:ঈমানী গল্প-২
# Book Author Name:মাওলানা যুলফিকার আহমদ নকশবন্দী
# Book Catagory:শিশু-কিশোর ইসলামি বই
# Original Price:TK. 500 tk
# Sell Price:TK. 315 tk
# Discount Rate:You Save TK. 185 (37%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:আকিক পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের ছোট গল্প: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:22:57 PM
# Book Title:ছোটদের ছোট গল্প
# Book Author Name:আব্দুল হামীদ আল-ফাইযী আল-মাদানী
# Book Catagory:ইসলামি গল্প
# Original Price:TK. 75 tk
# Sell Price:TK. 65 tk
# Discount Rate:You Save TK. 10 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:ওয়াহীদিয়া ইসলামিয়া লাইব্রেরী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বিশ্বসভ্যতার অগ্রনায়ক : সক্রেটিস, প্লেটো ও অ্যারিস্টটল: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:01 PM
# Book Title:বিশ্বসভ্যতার অগ্রনায়ক : সক্রেটিস, প্লেটো ও অ্যারিস্টটল
# Book Author Name:প্রফেসর ফিরোজা বেগম
# Book Catagory:বয়স যখন ১২-১৭: জীবনী গ্রন্থ
# Original Price:TK. 150 tk
# Sell Price:TK. 129 tk
# Discount Rate:You Save TK. 21 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:3.0
# Publication name:মেরিট ফেয়ার প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of পৃথিবীর ইতিহাস: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:02 PM
# Book Title:পৃথিবীর ইতিহাস
# Book Author Name:জওহরলাল নেহেরু
# Book Catagory:বয়স যখন ৮-১২: ইতিহাস ও রাজনীতি
# Original Price:TK. 150 tk
# Sell Price:TK. 129 tk
# Discount Rate:You Save TK. 21 (14%)
# Best seller merit:#10 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:ন্যাশনাল পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of রিচ ড্যাড পুওর ড্যাড: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:04 PM
# Book Title:রিচ ড্যাড পুওর ড্যাড
# Book Author Name:রবার্ট টি. কিয়োসাকি
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 350 tk
# Sell Price:TK. 300 tk
# Discount Rate:You Save TK. 50 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 95
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:দি ইউনিভার্সেল একাডেমি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গুপ্তধনের গুজব: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:05 PM
# Book Title:গুপ্তধনের গুজব
# Book Author Name:সুচিত্রা ভট্টাচার্য
# Book Catagory:পশ্চিমবঙ্গের বই: রহস্য, গোয়েন্দা, ভৌতিক, থ্রিলার ও অ্যাডভেঞ্চার
# Original Price: tk
# Sell Price:TK. 225 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:12
# Total Review:1
# Ratings:5.0
# Publication name:আনন্দ পাবলিশার্স (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of পূর্ব বাংলার ফটোগ্রাফি:রাজসাক্ষী গোলাম কাশেম ড্যাডি: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:07 PM
# Book Title:পূর্ব বাংলার ফটোগ্রাফি:রাজসাক্ষী গোলাম কাশেম ড্যাডি
# Book Author Name:নাসির আলী মামুন
# Book Catagory:সাহিত্যিক, শিল্প ও সংগীত ব্যক্তিত্ব
# Original Price:TK. 240 tk
# Sell Price:TK. 206 tk
# Discount Rate:You Save TK. 34 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:3
# Ratings:5.0
# Publication name:আদর্শ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের নির্বাচিত নজরুল: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:09 PM
# Book Title:ছোটদের নির্বাচিত নজরুল
# Book Author Name:কাজী নজরুল ইসলাম
# Book Catagory:শিশু-কিশোর: রচনাসমগ্র/সংকলন
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:কারুবাক
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of শিশু-কিশোর কবিতাসমগ্র: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:11 PM
# Book Title:শিশু-কিশোর কবিতাসমগ্র
# Book Author Name:সৈয়দ শামসুল হক
# Book Catagory:শিশু-কিশোর সাহিত্য/রচনা সমগ্র
# Original Price:TK. 350 tk
# Sell Price:TK. 311 tk
# Discount Rate:You Save TK. 39 (11%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:No
# Total Review:1
# Ratings:
# Publication name:মাওলা ব্রাদার্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ইখলাস: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:13 PM
# Book Title:ইখলাস
# Book Author Name:শাইখ সায়িদ ইবনু আলি আল-কাহতানি
# Book Catagory:ঈমান, আক্বিদা ও তাওবাহ
# Original Price:TK. 100 tk
# Sell Price:TK. 75 tk
# Discount Rate:You Save TK. 25 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:1
# Ratings:5.0
# Publication name:তাজকিয়া পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ম্যানস সার্চ ফর মিনিং: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:15 PM
# Book Title:ম্যানস সার্চ ফর মিনিং
# Book Author Name:ভিক্টর ই. ফ্র্যাঙ্কেল
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 300 tk
# Sell Price:TK. 258 tk
# Discount Rate:You Save TK. 42 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:অক্ষরবৃত্ত
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আসমানীর কবি ভাই: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:17 PM
# Book Title:আসমানীর কবি ভাই
# Book Author Name:জসীম উদদীন
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 170 tk
# Sell Price:TK. 128 tk
# Discount Rate:You Save TK. 42 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:4
# Ratings:5.0
# Publication name:পলাশ প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কিং অব কিংস: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:18 PM
# Book Title:কিং অব কিংস
# Book Author Name:উইলবার স্মিথ
# Book Catagory:থ্রিলার ও অ্যাডভেঞ্চার উপন্যাস
# Original Price:TK. 500 tk
# Sell Price:TK. 430 tk
# Discount Rate:You Save TK. 70 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:2
# Ratings:3.6
# Publication name:রোদেলা প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of হোম বিফোর ডার্ক: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:20 PM
# Book Title:হোম বিফোর ডার্ক
# Book Author Name:রাইলি স্যাগার
# Book Catagory:রহস্য, গোয়েন্দা, ভৌতিক, মিথ, থ্রিলার, ও অ্যাডভেঞ্চার: অনুবাদ ও ইংরেজি
# Original Price:TK. 500 tk
# Sell Price:TK. 392 tk
# Discount Rate:You Save TK. 108 (22%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:10
# Total Review:6
# Ratings:4.6
# Publication name:বাতিঘর প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of জেসমিন: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:23 PM
# Book Title:জেসমিন
# Book Author Name:মারগো লুনডেল
# Book Catagory:বয়স যখন ৮-১২: রূপকথা, উপকথা ও লোককাহিনী
# Original Price:TK. 75 tk
# Sell Price:TK. 65 tk
# Discount Rate:You Save TK. 10 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:সাহিত্য প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আর্সেন লুপাঁ ভার্সেস হার্লক শোমস: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:24 PM
# Book Title:আর্সেন লুপাঁ ভার্সেস হার্লক শোমস
# Book Author Name:মরিস লেবলাঁ
# Book Catagory:রহস্য, গোয়েন্দা, ভৌতিক, মিথ, থ্রিলার, ও অ্যাডভেঞ্চার: অনুবাদ ও ইংরেজি
# Original Price:TK. 420 tk
# Sell Price:TK. 329 tk
# Discount Rate:You Save TK. 91 (22%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:4.67
# Publication name:বেনজিন প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of সৃজনশীল পদ্ধতিতে স্কুল জ্যামিতি এবং তথ্য ও উপাত্ত: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:26 PM
# Book Title:সৃজনশীল পদ্ধতিতে স্কুল জ্যামিতি এবং তথ্য ও উপাত্ত
# Book Author Name:আবু মুসা সরকার
# Book Catagory:গণিত
# Original Price:TK. 600 tk
# Sell Price:TK. 516 tk
# Discount Rate:You Save TK. 84 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:No
# Ratings:4.6
# Publication name:বিজ্ঞান একাডেমী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কুচবরন রাজকন্যা: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:28 PM
# Book Title:কুচবরন রাজকন্যা
# Book Author Name:ডব্লিউসিবি (সম্পাদক)
# Book Catagory:বয়স যখন ৮-১২: রূপকথা, উপকথা ও লোককাহিনী
# Original Price:TK. 100 tk
# Sell Price:TK. 90 tk
# Discount Rate:You Save TK. 10 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:ওয়ার্ল্ড অব চিলড্রেন’স বুকস লিমিটেড
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of রয়েল বেঙ্গল রহস্য: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:29 PM
# Book Title:রয়েল বেঙ্গল রহস্য
# Book Author Name:সত্যজিৎ রায়
# Book Catagory:পশ্চিমবঙ্গের বই: শিশু-কিশোর বই
# Original Price:TK. 495 tk
# Sell Price:TK. 441 tk
# Discount Rate:You Save TK. 54 (11%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:11
# Total Review:4
# Ratings:5.0
# Publication name:আনন্দ পাবলিশার্স (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of শিশুতোষ রূপকথার গল্প : - ঠাকুরমার ঝুলি ১: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:31 PM
# Book Title:শিশুতোষ রূপকথার গল্প : - ঠাকুরমার ঝুলি ১
# Book Author Name:দক্ষিণারঞ্জন মিত্র মজুমদার
# Book Catagory:বয়স যখন ৪-৮: রূপকথা, উপকথা ও লোককাহিনী
# Original Price:TK. 140 tk
# Sell Price:TK. 88 tk
# Discount Rate:You Save TK. 52 (37%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:মেমোরী পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of টুকটুকি ও চেরাগের দৈত্য: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:33 PM
# Book Title:টুকটুকি ও চেরাগের দৈত্য
# Book Author Name:সিসিমপুর (সম্পাদক)
# Book Catagory:বয়স যখন ৪-৮: কমিক্স ও ছবির গল্প
# Original Price:TK. 315 tk
# Sell Price:TK. 271 tk
# Discount Rate:You Save TK. 44 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:সিসিমপুর
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of তিতাস একটি নদীর নাম: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:35 PM
# Book Title:তিতাস একটি নদীর নাম
# Book Author Name:অদ্বৈত মল্লবর্মণ
# Book Catagory:চিরায়ত উপন্যাস
# Original Price:TK. 285 tk
# Sell Price:TK. 245 tk
# Discount Rate:You Save TK. 40 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:5.0
# Publication name:বুক ক্লাব
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বিষাদ সিন্ধু: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:36 PM
# Book Title:বিষাদ সিন্ধু
# Book Author Name:মীর মশাররফ হোসেন
# Book Catagory:চিরায়ত উপন্যাস
# Original Price:TK. 300 tk
# Sell Price:TK. 210 tk
# Discount Rate:You Save TK. 90 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:8
# Total Review:4
# Ratings:4.38
# Publication name:সোলেমানিয়া বুক হাউস
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of প্রাইড এন্ড প্রেজুডিস: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:38 PM
# Book Title:প্রাইড এন্ড প্রেজুডিস
# Book Author Name:জেন অস্টেন
# Book Catagory:অনুবাদ উপন্যাস
# Original Price:TK. 135 tk
# Sell Price:TK. 108 tk
# Discount Rate:You Save TK. 27 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:4.75
# Publication name:ফ্রেন্ডস্ বুক কর্ণার
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of সামাজিক ন্যায়বিচার: 101
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:40 PM
# Book Title:সামাজিক ন্যায়বিচার
# Book Author Name:জন রলস
# Book Catagory:আইন সম্পর্কিত বিবিধ বই
# Original Price:TK. 150 tk
# Sell Price:TK. 129 tk
# Discount Rate:You Save TK. 21 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:4.0
# Publication name:নিউ নভেল পাবলিশিং হাউস
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
#
#
# ---------------data is loaded of 101---------
#
#
# ---------------data is loading from 102---------
#
#
# Information of মামার বাড়ির ভূত: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:43 PM
# Book Title:মামার বাড়ির ভূত
# Book Author Name:সরোজ আহমেদ
# Book Catagory:বয়স যখন ৮-১২: গল্প
# Original Price:TK. 130 tk
# Sell Price:TK. 80 tk
# Discount Rate:You Save TK. 50 (38%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:গাজী প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ৯০ দশকের নির্বাচিত পাঁচটি উপন্যাস: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:44 PM
# Book Title:৯০ দশকের নির্বাচিত পাঁচটি উপন্যাস
# Book Author Name:হুমায়ূন আহমেদ
# Book Catagory:উপন্যাস সমগ্র
# Original Price:TK. 600 tk
# Sell Price:TK. 516 tk
# Discount Rate:You Save TK. 84 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:অন্যপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of করোনা পরবর্তী বিশ্বরাজনীতি: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:46 PM
# Book Title:করোনা পরবর্তী বিশ্বরাজনীতি
# Book Author Name:ড. তারেক শামসুর রেহমান
# Book Catagory:রাজনৈতিক গবেষণা ও প্রবন্ধ
# Original Price:TK. 275 tk
# Sell Price:TK. 237 tk
# Discount Rate:You Save TK. 38 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 74
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:শোভা প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of চার মাযহাব উৎপত্তি ও ক্রমবিকাশ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:48 PM
# Book Title:চার মাযহাব উৎপত্তি ও ক্রমবিকাশ
# Book Author Name:হযরতুল আল্লামা মাওলানা ইয়াহইয়া নুমানী নদবী
# Book Catagory:ইসলামি গবেষণা, সমালোচনা ও প্রবন্ধ
# Original Price:TK. 240 tk
# Sell Price:TK. 144 tk
# Discount Rate:You Save TK. 96 (40%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:5.0
# Publication name:আশরাফিয়া বুক হাউস
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of সাফল্য অর্জনের উপায়: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:50 PM
# Book Title:সাফল্য অর্জনের উপায়
# Book Author Name:নেসার আমিন
# Book Catagory:আত্ম উন্নয়ন ও মোটিভেশন
# Original Price:TK. 270 tk
# Sell Price:TK. 232 tk
# Discount Rate:You Save TK. 38 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 73
# Total Ratings:2
# Total Review:No
# Ratings:4.0
# Publication name:সূচীপত্র
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য ক্যাচার ইন দ্য রাই: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:54 PM
# Book Title:দ্য ক্যাচার ইন দ্য রাই
# Book Author Name:জে ডি সালিঞ্জার
# Book Catagory:অনুবাদ উপন্যাস
# Original Price:TK. 450 tk
# Sell Price:TK. 387 tk
# Discount Rate:You Save TK. 63 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:3
# Ratings:1.0
# Publication name:বাতিঘর
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ইংরেজি ভাষার ইতিহাস: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:56 PM
# Book Title:ইংরেজি ভাষার ইতিহাস
# Book Author Name:জি এইচ হাবীব (অনুবাদক)
# Book Catagory:ভাষা বিষয়ক গবেষণা, প্রবন্ধ ও সমালোচনা
# Original Price:TK. 250 tk
# Sell Price:TK. 215 tk
# Discount Rate:You Save TK. 35 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:7
# Total Review:4
# Ratings:4.29
# Publication name:কথাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য ট্র্যাভেলিং ক্যাট ক্রনিক্যালস: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:58 PM
# Book Title:দ্য ট্র্যাভেলিং ক্যাট ক্রনিক্যালস
# Book Author Name:হিরো আরিকাওয়া
# Book Catagory:অনুবাদ উপন্যাস
# Original Price:TK. 370 tk
# Sell Price:TK. 318 tk
# Discount Rate:You Save TK. 52 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:4
# Ratings:4.8
# Publication name:অবসর প্রকাশনা সংস্থা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ফৌজদারী কার্যবিধি : তত্ত্ব ও বিশ্লেষণ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:23:59 PM
# Book Title:ফৌজদারী কার্যবিধি : তত্ত্ব ও বিশ্লেষণ
# Book Author Name:ব্যারিস্টার মোঃ আব্দুল হালিম
# Book Catagory:ক্রিমিনাল ল টপিকস্
# Original Price:TK. 800 tk
# Sell Price:TK. 584 tk
# Discount Rate:You Save TK. 216 (27%)
# Best seller merit:#1 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:9
# Total Review:3
# Ratings:4.0
# Publication name:দ্য সিসিবি বুক সেন্টার
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of না বলতে শিখুন: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:01 PM
# Book Title:না বলতে শিখুন
# Book Author Name:জাবেদ ইমন (অনুবাদক)
# Book Catagory:আত্ম উন্নয়ন ও মোটিভেশন
# Original Price:TK. 260 tk
# Sell Price:TK. 224 tk
# Discount Rate:You Save TK. 36 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:2
# Ratings:5.0
# Publication name:মুক্তদেশ প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ২৫ শে মার্চ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:03 PM
# Book Title:২৫ শে মার্চ
# Book Author Name:রবিন জামান খান
# Book Catagory:থ্রিলার
# Original Price:TK. 500 tk
# Sell Price:TK. 448 tk
# Discount Rate:You Save TK. 52 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:6
# Total Review:3
# Ratings:4.5
# Publication name:নালন্দা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of মা-বাবা: আমার জান্নাত: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:06 PM
# Book Title:মা-বাবা: আমার জান্নাত
# Book Author Name:ইবনুল জাওযী রহ.
# Book Catagory:পারিবারিক জীবনবিধান
# Original Price:TK. 110 tk
# Sell Price:TK. 83 tk
# Discount Rate:You Save TK. 27 (25%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 30
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:আযান প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of সহজ উপায়ে ৩০ দিনে কুয়েতি ভাষা শিখুন: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:09 PM
# Book Title:সহজ উপায়ে ৩০ দিনে কুয়েতি ভাষা শিখুন
# Book Author Name:মোঃ আবু বকর সিদ্দিক (সম্পাদক)
# Book Catagory:Middle-Eastern Language
# Original Price:TK. 150 tk
# Sell Price:TK. 87 tk
# Discount Rate:You Save TK. 63 (42%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Monihar Book Dipo
# Language:Bangla, English, Arabic
# Country name:Bangladesh
# -----------------
#
#
# Information of নেটওয়ার্ক মার্কেটিং ব্যবসায় সাফল্যের কলাকৌশল: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:11 PM
# Book Title:নেটওয়ার্ক মার্কেটিং ব্যবসায় সাফল্যের কলাকৌশল
# Book Author Name:গাজী কামরুল ইসলাম
# Book Catagory:ক্যারিয়ার উন্নয়ন
# Original Price:TK. 300 tk
# Sell Price:TK. 269 tk
# Discount Rate:You Save TK. 31 (10%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 135
# Total Ratings:5
# Total Review:2
# Ratings:4.6
# Publication name:বাক্য প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of হাদিস আল-কিসা: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:15 PM
# Book Title:হাদিস আল-কিসা
# Book Author Name:নূরে আলম মুহাম্মাদী (অনুবাদক)
# Book Catagory:হাদিস বিষয়ক আলোচনা
# Original Price:TK. 55 tk
# Sell Price:TK. 39 tk
# Discount Rate:You Save TK. 16 (29%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 25
# Total Ratings:2
# Total Review:2
# Ratings:5.0
# Publication name:আলে রাসূল পাবলিকেশনস্
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ১০০ সুসাব্যস্ত সুন্নাত: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:18 PM
# Book Title:১০০ সুসাব্যস্ত সুন্নাত
# Book Author Name:আয-যুলফি দা‘ওয়াহ সেন্টার
# Book Catagory:হাদিস ও সুন্নাত
# Original Price:TK. 100 tk
# Sell Price:TK. 70 tk
# Discount Rate:You Save TK. 30 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:আলোকিত প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of হোমারের অডিসি: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:22 PM
# Book Title:হোমারের অডিসি
# Book Author Name:সিরাজুল ইসলাম চৌধুরী
# Book Catagory:বয়স যখন ১২-১৭: রহস্য, গোয়েন্দা, থ্রিলার ও অ্যাডভেঞ্চার
# Original Price:TK. 300 tk
# Sell Price:TK. 258 tk
# Discount Rate:You Save TK. 42 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:বাঙ্গালা গবেষণা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কথিত আহলে হাদীসের প্রতি ওপেন চ্যালেঞ্জ হাদিসের আলোকে নবীজীর (স) ৩০ প্রকার নামাজ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:24 PM
# Book Title:কথিত আহলে হাদীসের প্রতি ওপেন চ্যালেঞ্জ হাদিসের আলোকে নবীজীর (স) ৩০ প্রকার নামাজ
# Book Author Name:হাফেজ মাওলানা মুফতী আব্দুর রহমান আজাদ
# Book Catagory:সালাত/নামায
# Original Price:TK. 500 tk
# Sell Price:TK. 335 tk
# Discount Rate:You Save TK. 165 (33%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:3.0
# Publication name:মাহমুদ পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of প্রতিভাকে অর্থে পরিণত করুন: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:26 PM
# Book Title:প্রতিভাকে অর্থে পরিণত করুন
# Book Author Name:আইজাক জন আকাণ্ড
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 120 tk
# Sell Price:TK. 103 tk
# Discount Rate:You Save TK. 17 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:7
# Total Review:4
# Ratings:5.0
# Publication name:জ্ঞান বিতরণী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of জগদীশচন্দ্র বসু: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:27 PM
# Book Title:জগদীশচন্দ্র বসু
# Book Author Name:নিখিলেশ ঘোষ
# Book Catagory:বিজ্ঞানী
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:No
# Total Review:1
# Ratings:
# Publication name:কথাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বিজয়ের মুহূর্ত ১৯৭১: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:31 PM
# Book Title:বিজয়ের মুহূর্ত ১৯৭১
# Book Author Name:মতিউর রহমান
# Book Catagory:প্রসঙ্গ: মুক্তিযুদ্ধ
# Original Price:TK. 250 tk
# Sell Price:TK. 224 tk
# Discount Rate:You Save TK. 26 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:প্রথমা প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য 7 হ্যাবিটস অব হাইলি ইফেকটিভ পিপল: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:35 PM
# Book Title:দ্য 7 হ্যাবিটস অব হাইলি ইফেকটিভ পিপল
# Book Author Name:স্টিফেন আর. কোভি
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 450 tk
# Sell Price:TK. 373 tk
# Discount Rate:You Save TK. 77 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:8
# Total Review:7
# Ratings:1.38
# Publication name:রচনা প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ফেস্টিভ্যাল: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:37 PM
# Book Title:ফেস্টিভ্যাল
# Book Author Name:এইচ পি লাভক্র্যাফট
# Book Catagory:থ্রিলার
# Original Price:TK. 250 tk
# Sell Price:TK. 215 tk
# Discount Rate:You Save TK. 35 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:4.75
# Publication name:আফসার ব্রাদার্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ইউ ক্যান সেল: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:38 PM
# Book Title:ইউ ক্যান সেল
# Book Author Name:শিব খেরা
# Book Catagory:ক্যারিয়ার উন্নয়ন
# Original Price:TK. 400 tk
# Sell Price:TK. 332 tk
# Discount Rate:You Save TK. 68 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:দি স্কাই পাবলিশার্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আমার একটা পোষা দৈত্য আছে: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:40 PM
# Book Title:আমার একটা পোষা দৈত্য আছে
# Book Author Name:আনিসুল হক
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 90 tk
# Sell Price:TK. 77 tk
# Discount Rate:You Save TK. 13 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:4.5
# Publication name:পাঞ্জেরী পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের শিক্ষামূলক গল্প: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:41 PM
# Book Title:ছোটদের শিক্ষামূলক গল্প
# Book Author Name:আবু তাহের
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 200 tk
# Sell Price:TK. 166 tk
# Discount Rate:You Save TK. 34 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:ঝিনুক প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of অ্যাসটেরিক্স ও ক্লিওপেট্টা: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:42 PM
# Book Title:অ্যাসটেরিক্স ও ক্লিওপেট্টা
# Book Author Name:রনে গোসিনি
# Book Catagory:পশ্চিমবঙ্গের বই: কমিকস ও ছবির গল্প
# Original Price:TK. 630 tk
# Sell Price:TK. 561 tk
# Discount Rate:You Save TK. 69 (11%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:12
# Total Review:No
# Ratings:4.92
# Publication name:আনন্দ পাবলিশার্স (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of গোপাল ভাঁড়ের ৫ ডজন গল্প: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:44 PM
# Book Title:গোপাল ভাঁড়ের ৫ ডজন গল্প
# Book Author Name:আখতার হুসেন (সম্পাদক)
# Book Catagory:শিশু-কিশোর: রম্য ও ব্যঙ্গ রচনা
# Original Price:TK. 220 tk
# Sell Price:TK. 197 tk
# Discount Rate:You Save TK. 23 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:প্রথমা প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আবু বকর সিদ্দিক রা.: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:45 PM
# Book Title:আবু বকর সিদ্দিক রা.
# Book Author Name:ড. আলী মুহাম্মদ সাল্লাবি
# Book Catagory:নবি-রাসুল, সাহাবা, তাবেই ও অলি-আওলিয়া
# Original Price:TK. 690 tk
# Sell Price:TK. 518 tk
# Discount Rate:You Save TK. 172 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:18
# Total Review:14
# Ratings:4.89
# Publication name:কালান্তর প্রকাশনী (সিলেট)
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of পদার্থবিদ্যার বিচিত্র জগৎ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:47 PM
# Book Title:পদার্থবিদ্যার বিচিত্র জগৎ
# Book Author Name:আব্দুল গাফফার রনি
# Book Catagory:পদার্থবিজ্ঞান
# Original Price:TK. 300 tk
# Sell Price:TK. 258 tk
# Discount Rate:You Save TK. 42 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:3
# Ratings:4.8
# Publication name:বিশ্বসাহিত্য ভবন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গন্তব্য: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:49 PM
# Book Title:গন্তব্য
# Book Author Name:শফিক মুন্সি
# Book Catagory:ইসলামি বই: আত্ম-উন্নয়ন
# Original Price:TK. 110 tk
# Sell Price:TK. 72 tk
# Discount Rate:You Save TK. 38 (35%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:মুহাম্মদ পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ঈগল পাখি কোথায় গেল? (কোড-১৪৬): 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:51 PM
# Book Title:ঈগল পাখি কোথায় গেল? (কোড-১৪৬)
# Book Author Name:আহমেদ খান হীরক
# Book Catagory:বয়স যখন ৪-৮: কমিক্স ও ছবির গল্প
# Original Price:TK. 120 tk
# Sell Price:TK. 103 tk
# Discount Rate:You Save TK. 17 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:সিসিমপুর
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গণিতের সূত্রাবলি: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:52 PM
# Book Title:গণিতের সূত্রাবলি
# Book Author Name:মো. ইউনুস মিয়া
# Book Catagory:রেফারেন্স বই
# Original Price:TK. 60 tk
# Sell Price:TK. 45 tk
# Discount Rate:You Save TK. 15 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:4.0
# Publication name:উইনটন পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of এবং যখন চলে যাব: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:53 PM
# Book Title:এবং যখন চলে যাব
# Book Author Name:ফুয়াদ শহীদ
# Book Catagory:বাংলা কবিতা
# Original Price:TK. 280 tk
# Sell Price:TK. 241 tk
# Discount Rate:You Save TK. 39 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:অন্যপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বিদায়াতুল আরাবিয়া (আরবির শুরু) - দ্বিতীয় ভাগ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:54 PM
# Book Title:বিদায়াতুল আরাবিয়া (আরবির শুরু) - দ্বিতীয় ভাগ
# Book Author Name:এস এম নাহিদ হাসান (সম্পাদক)
# Book Catagory:আরবি শিক্ষা
# Original Price: tk
# Sell Price:TK. 330 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Al Quraner Vasha Institute
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ঘনাদা সমগ্র ২: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:55 PM
# Book Title:ঘনাদা সমগ্র ২
# Book Author Name:প্রেমেন্দ্র মিত্র
# Book Catagory:পশ্চিমবঙ্গের বই: রচনাসমগ্র ও সংকলন
# Original Price: tk
# Sell Price:TK. 1,800 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:1
# Ratings:5.0
# Publication name:আনন্দ পাবলিশার্স (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of ফেরারি প্রেমিকা: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:57 PM
# Book Title:ফেরারি প্রেমিকা
# Book Author Name:কাসেম বিন আবুবাকার
# Book Catagory:রোমান্টিক উপন্যাস
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:3
# Ratings:5.0
# Publication name:আলেয়া বুক ডিপো
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কাগজের পুরুষ: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:24:58 PM
# Book Title:কাগজের পুরুষ
# Book Author Name:অধরা জাহান
# Book Catagory:সমকালীন উপন্যাস
# Original Price:TK. 334 tk
# Sell Price:TK. 299 tk
# Discount Rate:You Save TK. 35 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:তাম্রলিপি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of অরক্ষণীয়া: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:25:01 PM
# Book Title:অরক্ষণীয়া
# Book Author Name:মোর্শেদা হোসেন রুবী
# Book Catagory:সমকালীন উপন্যাস
# Original Price:TK. 470 tk
# Sell Price:TK. 404 tk
# Discount Rate:You Save TK. 66 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:6
# Total Review:1
# Ratings:5.0
# Publication name:বইবাজার প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of তোমার অপেক্ষায়: 102
#
#
# Current Date: 2024-04-15
# Current Time: 09:25:05 PM
# Book Title:তোমার অপেক্ষায়
# Book Author Name:মিজানুর রহমান হৃদয়
# Book Catagory:রোমান্টিক উপন্যাস
# Original Price:TK. 200 tk
# Sell Price:TK. 172 tk
# Discount Rate:You Save TK. 28 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# ...
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বাংলাদেশের কৃষি অর্থনীতি: বিষয় ও বিশ্লেষণ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:43 PM
# Book Title:বাংলাদেশের কৃষি অর্থনীতি: বিষয় ও বিশ্লেষণ
# Book Author Name:এম এ সাত্তার মণ্ডল
# Book Catagory:কৃষি প্রযুক্তি ও অর্থনীতি
# Original Price:TK. 580 tk
# Sell Price:TK. 510 tk
# Discount Rate:You Save TK. 70 (12%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:দি ইউনিভার্সিটি প্রেস লিমিটেড(ইউ পি এল)
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের রাজনীতি ও ছোটদের অর্থনীতি: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:46 PM
# Book Title:ছোটদের রাজনীতি ও ছোটদের অর্থনীতি
# Book Author Name:ড. নীহার কুমার সরকার
# Book Catagory:শিশু-কিশোর: প্রবন্ধ
# Original Price:TK. 300 tk
# Sell Price:TK. 258 tk
# Discount Rate:You Save TK. 42 (14%)
# Best seller merit:#6 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:3.0
# Publication name:ধ্রুপদ সাহিত্যাঙ্গন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ঈশ্বরচন্দ্র বিদ্যাসাগর: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:49 PM
# Book Title:ঈশ্বরচন্দ্র বিদ্যাসাগর
# Book Author Name:রাশেদুল আনাম
# Book Catagory:সমাজসেবক ও সংস্কারক
# Original Price:TK. 130 tk
# Sell Price:TK. 112 tk
# Discount Rate:You Save TK. 18 (14%)
# Best seller merit:#8 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:কথাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য মিরাকল মর্নিং: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:52 PM
# Book Title:দ্য মিরাকল মর্নিং
# Book Author Name:হ্যাল এলরড
# Book Catagory:অনুবাদ: আত্ম-উন্নয়ন ও মেডিটেশন
# Original Price:TK. 320 tk
# Sell Price:TK. 192 tk
# Discount Rate:You Save TK. 128 (40%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:No
# Total Review:1
# Ratings:
# Publication name:অনুভূতি প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের বিজ্ঞান জগৎ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:55 PM
# Book Title:ছোটদের বিজ্ঞান জগৎ
# Book Author Name:সুকুমার রায়
# Book Catagory:ছোটদের গণিত, বিজ্ঞান ও প্রযুক্তি
# Original Price:TK. 300 tk
# Sell Price:TK. 235 tk
# Discount Rate:You Save TK. 65 (22%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:রিয়া প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কখনো ফুরোবে না এই ভালোবাসা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:33:57 PM
# Book Title:কখনো ফুরোবে না এই ভালোবাসা
# Book Author Name:আবুল হাসান ওয়ায়েলি
# Book Catagory:ব্যক্তিগত জীবনবিধান
# Original Price:TK. 134 tk
# Sell Price:TK. 94 tk
# Discount Rate:You Save TK. 40 (30%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 33
# Total Ratings:2
# Total Review:No
# Ratings:4.0
# Publication name:রুহামা পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য কিল সুইচ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:00 PM
# Book Title:দ্য কিল সুইচ
# Book Author Name:জেমস রলিন্স
# Book Catagory:থ্রিলার
# Original Price:TK. 500 tk
# Sell Price:TK. 430 tk
# Discount Rate:You Save TK. 70 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:6
# Total Review:1
# Ratings:3.67
# Publication name:বিবলিওফাইল প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দ্য কমেডি অব এররস: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:02 PM
# Book Title:দ্য কমেডি অব এররস
# Book Author Name:উইলিয়াম শেক্সপীয়ার
# Book Catagory:বয়স যখন ৮-১২: রম্য ও ব্যঙ্গ রচনা
# Original Price:TK. 60 tk
# Sell Price:TK. 52 tk
# Discount Rate:You Save TK. 8 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:3.0
# Publication name:বাংলাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of পদার্থবিজ্ঞান (ব্যবহারিক নোট বুক): 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:04 PM
# Book Title:পদার্থবিজ্ঞান (ব্যবহারিক নোট বুক)
# Book Author Name:পেপারসফট প্রকাশনী (সম্পাদক)
# Book Catagory:ষ্টেশনারি
# Original Price:TK. 100 tk
# Sell Price:TK. 90 tk
# Discount Rate:You Save TK. 10 (10%)
# Best seller merit:#10 Best Seller
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:2
# Ratings:4.0
# Publication name:পেপারসফট
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of খুদে রহস্য গল্প: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:07 PM
# Book Title:খুদে রহস্য গল্প
# Book Author Name:সাহিত্য প্রকাশ
# Book Catagory:বয়স যখন ৪-৮: কমিক্স ও ছবির গল্প
# Original Price:TK. 75 tk
# Sell Price:TK. 65 tk
# Discount Rate:You Save TK. 10 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:5.0
# Publication name:সাহিত্য প্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of দৃষ্টি সংযত রাখুন: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:09 PM
# Book Title:দৃষ্টি সংযত রাখুন
# Book Author Name:(شيخ الاسلام مفتي محمد تقي عثماني) শাইখুল ইসলাম মুফতী মুহাম্মাদ তাকী উসমানী
# Book Catagory:ইসলামি গবেষণা, সমালোচনা ও প্রবন্ধ
# Original Price:TK. 230 tk
# Sell Price:TK. 138 tk
# Discount Rate:You Save TK. 92 (40%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:মাকতাবাতুল আরাফ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটা ভীম : সাগরকন্যা শের (৩য় গল্প): 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:12 PM
# Book Title:ছোটা ভীম : সাগরকন্যা শের (৩য় গল্প)
# Book Author Name:হীরেন চট্টোপাধ্যায় (অনুবাদক)
# Book Catagory:পশ্চিমবঙ্গের বই: কমিকস ও ছবির গল্প
# Original Price: tk
# Sell Price:TK. 120 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:No
# Ratings:5.0
# Publication name:ছায়া প্রকাশনী প্রা: লিঃ (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of হুহুপাখি আর রাখালের আকাশ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:14 PM
# Book Title:হুহুপাখি আর রাখালের আকাশ
# Book Author Name:সোনিকা ইসলাম
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 50 tk
# Sell Price:TK. 45 tk
# Discount Rate:You Save TK. 5 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:দুন্দুভি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটমণিদের গল্পের ঝুলি (বেগুনী বই): 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:17 PM
# Book Title:ছোটমণিদের গল্পের ঝুলি (বেগুনী বই)
# Book Author Name:আজিজুর রহমান (সম্পাদক)
# Book Catagory:বয়স যখন ৪-৮: গল্প ও কাহিনী
# Original Price:TK. 60 tk
# Sell Price:TK. 52 tk
# Discount Rate:You Save TK. 8 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:নলেজ ভিউ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of বুদ্ধির গল্প: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:20 PM
# Book Title:বুদ্ধির গল্প
# Book Author Name:হো লাই লিন
# Book Catagory:বয়স যখন ১২-১৭: কমিকস ও ছবির গল্প
# Original Price:TK. 200 tk
# Sell Price:TK. 172 tk
# Discount Rate:You Save TK. 28 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:5.0
# Publication name:পাঞ্জেরী পাবলিকেশন্স
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of মাই পিকচার ওয়ার্ড বুক- ১ কাওমী মাদ্রাসা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:22 PM
# Book Title:মাই পিকচার ওয়ার্ড বুক- ১ কাওমী মাদ্রাসা
# Book Author Name:ইসলামিয়া কুতুবখানা
# Book Catagory:কওমি: কেজি ও প্রথম শ্রেণি
# Original Price:TK. 60 tk
# Sell Price:TK. 58 tk
# Discount Rate:You Save TK. 2 (3%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:ইসলামিয়া কুতুবখানা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of এসো জীবনকে পরিবর্তন করি: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:24 PM
# Book Title:এসো জীবনকে পরিবর্তন করি
# Book Author Name:এহসান উল্লাহ আরাফাত
# Book Catagory:ইসলামি বই: আত্ম উন্নয়ন
# Original Price:TK. 200 tk
# Sell Price:TK. 120 tk
# Discount Rate:You Save TK. 80 (40%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:4
# Total Review:2
# Ratings:5.0
# Publication name:আয়াত প্রকাশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of শটিমটি: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:27 PM
# Book Title:শটিমটি
# Book Author Name:মোঃ শাহ আলম
# Book Catagory:বয়স যখন ৪-৮: কমিক্স ও ছবির গল্প
# Original Price:TK. 100 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 14 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:1
# Ratings:5.0
# Publication name:সিসিমপুর
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গল্পে গল্পে নীতিশিক্ষা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:30 PM
# Book Title:গল্পে গল্পে নীতিশিক্ষা
# Book Author Name:রাম শংকর দেবনাথ (সম্পাদক)
# Book Catagory:শিশু-কিশোর গল্প
# Original Price:TK. 80 tk
# Sell Price:TK. 69 tk
# Discount Rate:You Save TK. 11 (14%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 22
# Total Ratings:3
# Total Review:1
# Ratings:3.0
# Publication name:বিভাস
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of আগাথা ক্রিস্টি সমগ্র ৬: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:32 PM
# Book Title:আগাথা ক্রিস্টি সমগ্র ৬
# Book Author Name:আগাথা ক্রিস্টি
# Book Catagory:রহস্য, গোয়েন্দা, ভৌতিক, মিথ, থ্রিলার, ও অ্যাডভেঞ্চার: অনুবাদ ও ইংরেজি
# Original Price:TK. 700 tk
# Sell Price:TK. 602 tk
# Discount Rate:You Save TK. 98 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:5.0
# Publication name:বিবলিওফাইল প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of টারজান -৪: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:35 PM
# Book Title:টারজান -৪
# Book Author Name:এডগার রাইস বারোজ
# Book Catagory:রহস্য, গোয়েন্দা, ভৌতিক, মিথ, থ্রিলার, ও অ্যাডভেঞ্চার: অনুবাদ ও ইংরেজি
# Original Price:TK. 420 tk
# Sell Price:TK. 361 tk
# Discount Rate:You Save TK. 59 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:প্রতীক প্রকাশনা সংস্থা
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of প্রসিদ্ধ - ফুল: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:37 PM
# Book Title:প্রসিদ্ধ - ফুল
# Book Author Name:প্রদীপ রায়
# Book Catagory:When 0-4: Primary Learning
# Original Price:TK. 120 tk
# Sell Price:TK. 103 tk
# Discount Rate:You Save TK. 17 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Prasiddha Publishers
# Language:Bangla & English
# Country name:Bangladesh
# -----------------
#
#
# Information of বাড়ি ফেরা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:41 PM
# Book Title:বাড়ি ফেরা
# Book Author Name:ইফতেখার আহমেদ
# Book Catagory:কমিক্স বই
# Original Price:TK. 120 tk
# Sell Price:TK. 90 tk
# Discount Rate:You Save TK. 30 (25%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:1
# Ratings:3.5
# Publication name:রঙ্গন পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of কর্নেল সমগ্র ১৭: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:44 PM
# Book Title:কর্নেল সমগ্র ১৭
# Book Author Name:সৈয়দ মুস্তাফা সিরাজ
# Book Catagory:পশ্চিমবঙ্গের বই: রহস্য, গোয়েন্দা, ভৌতিক, থ্রিলার ও অ্যাডভেঞ্চার
# Original Price: tk
# Sell Price:TK. 540 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:5
# Total Review:No
# Ratings:5.0
# Publication name:দে’জ পাবলিশিং (ভারত)
# Language:বাংলা
# Country name:ভারত
# -----------------
#
#
# Information of দেওয়ানী কার্যবিধি : তত্ত্ব ও বিশ্লেষণ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:46 PM
# Book Title:দেওয়ানী কার্যবিধি : তত্ত্ব ও বিশ্লেষণ
# Book Author Name:ব্যারিস্টার মোঃ আব্দুল হালিম
# Book Catagory:আইন সম্পর্কিত বিবিধ বই
# Original Price:TK. 700 tk
# Sell Price:TK. 476 tk
# Discount Rate:You Save TK. 224 (32%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:2
# Ratings:3.67
# Publication name:দ্য সিসিবি বুক সেন্টার
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of এখনো কি ফিরে আসার সময় হয়নি?: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:49 PM
# Book Title:এখনো কি ফিরে আসার সময় হয়নি?
# Book Author Name:শাইখ খালিদ আর রশিদ
# Book Catagory:ইসলামি বই: আত্ম-উন্নয়ন
# Original Price:TK. 380 tk
# Sell Price:TK. 266 tk
# Discount Rate:You Save TK. 114 (30%)
# Best seller merit:
# E-book availability:Yes
# E-book price:TK. 96
# Total Ratings:3
# Total Review:No
# Ratings:3.67
# Publication name:রুহামা পাবলিকেশন
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of অভিশপ্ত পৌরাণিক চরিত্র: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:53 PM
# Book Title:অভিশপ্ত পৌরাণিক চরিত্র
# Book Author Name:জ্যোতির্ময় সেন
# Book Catagory:হিন্দু ধর্মীয় বই
# Original Price:TK. 500 tk
# Sell Price:TK. 400 tk
# Discount Rate:You Save TK. 100 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:কথাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ১০০ হোজ্জা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:56 PM
# Book Title:১০০ হোজ্জা
# Book Author Name:হাশিম মিলন
# Book Catagory:বয়স যখন ১২-১৭: গল্প
# Original Price:TK. 140 tk
# Sell Price:TK. 120 tk
# Discount Rate:You Save TK. 20 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:3.0
# Publication name:ছোটদের বই
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ছোটদের হাদিসের কাহিনি: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:34:59 PM
# Book Title:ছোটদের হাদিসের কাহিনি
# Book Author Name:আমীরুল ইসলাম
# Book Catagory:বয়স যখন ৮-১২: ধর্মীয় বই
# Original Price:TK. 175 tk
# Sell Price:TK. 140 tk
# Discount Rate:You Save TK. 35 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:তূর্য প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of ত্রিনিয়া: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:35:02 PM
# Book Title:ত্রিনিয়া
# Book Author Name:নাবিলা আনজুম জামান
# Book Catagory:বয়স যখন ১২-১৭: সায়েন্স ফিকশন
# Original Price:TK. 120 tk
# Sell Price:TK. 103 tk
# Discount Rate:You Save TK. 17 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:6
# Total Review:2
# Ratings:3.17
# Publication name:এবং মানুষ প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of মহাভারতের দেশ: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:35:06 PM
# Book Title:মহাভারতের দেশ
# Book Author Name:আবুল ফজল
# Book Catagory:হিন্দু ধর্মীয় বই
# Original Price:TK. 400 tk
# Sell Price:TK. 320 tk
# Discount Rate:You Save TK. 80 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:কথাপ্রকাশ
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
# Information of গুনাহ তাওবা ক্ষমা: 127
#
#
# Current Date: 2024-04-15
# Current Time: 10:35:10 PM
# Book Title:গুনাহ তাওবা ক্ষমা
# Book Author Name:মাওলানা আবদুস শহীদ নাসিম
# Book Catagory:মৃত্যু, পরকাল ও জান্নাত-জাহান্নাম
# Original Price:TK. 200 tk
# Sell Price:TK. 140 tk
# Discount Rate:You Save TK. 60 (30%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:2
# Ratings:5.0
# Publication name:বর্ণালি বুক সেন্টার-বিবিসি
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
#
#
#
#
# ---------------data is loaded of 127---------
#
#
# ---------------data is loading from 128---------
#
#
# Information of শ্রেষ্ঠ লোক সঙ্গীতের স্বরলিপি: 128
#
#
# Current Date: 2024-04-15
# Current Time: 10:35:18 PM
# Book Title:শ্রেষ্ঠ লোক সঙ্গীতের স্বরলিপি
# Book Author Name:শঙ্কর রায়
# Book Catagory:স্বরলিপি
# Original Price:TK. 175 tk
# Sell Price:TK. 151 tk
# Discount Rate:You Save TK. 24 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:5.0
# Publication name:অঞ্জলি প্রকাশনী
# Language:বাংলা
# Country name:বাংলাদেশ
# -----------------
