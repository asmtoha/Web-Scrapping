# %%
from bs4 import BeautifulSoup
import requests
import time
from datetime import datetime
from urllib.parse import urljoin
from openpyxl import Workbook
import pytz

# %%
bst = pytz.timezone('Asia/Dhaka')

#create a new Workbook
wb = Workbook()
#create a new worksheet
ws = wb.active
#add headers to the first row of the worksheet
headers = ["Date", "Time","Book Title", "Author", "Category", "Original Price", "Sell Price", "Discount", "Best Seller Merit", "E-book Availability", "E-book Price", "Ratings Count",
           "Reviews Count", "Rating", "Publisher", "Language", "Country","Page_Number"]
ws.append(headers)

# %%
saved = "C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx"
total_page = 166
page_number = 101
while page_number <= total_page:
    
    print(f"---------------data is loading from {page_number}---------\n\n")
    #make connection with website
    url = 'https://www.rokomari.com/search?term=product&search_type=SUPER_STORE&page='+ str(page_number)
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}
    page = requests.get(url,headers=headers)   
    soup_1 = BeautifulSoup(page.content,"html.parser")  
    soup_2 = BeautifulSoup(soup_1.prettify(),"html.parser")    
    books_div_area = soup_2.find_all("div",class_='book-list-wrapper')   
    book_links = [elem.find("a").get('href') for elem in books_div_area]

    
    for link in book_links:
        
        full_link = urljoin(url, link)  # Concatenating the base URL with the link
        book_page = requests.get(full_link, headers=headers)
        book_soup = BeautifulSoup(book_page.content, "html.parser")
        book_soup_prettify = BeautifulSoup(book_soup.prettify(),"html.parser")
        #pillar
        main_header_1 = book_soup_prettify.find("div",class_="col details-book-main-info align-self-center")
        main_header_2 = book_soup_prettify.find("div",class_="details-stationary__details h-100")
        books_header_1 = book_soup_prettify.find("div", class_="details-book-main-info__header") 
        books_header_2 = book_soup_prettify.find("div",class_="details-stationary__details h-100")
        additional_info_1 = book_soup_prettify.find("div",id="book-additional-specification")
        additional_info_2 = book_soup_prettify.find("table",class_="specification-section__table border-top pt-3 mt-4")      
        #initialize variables
        book_title = book_author = category = original_price = sell_price = discount = best_seller_merit = ebook_availability = ebook_price = ratings_count = reviews_count = rating = publisher_name = country_name = language_name = ""
    
        if main_header_1 and books_header_1: 
            
            current_date = datetime.now().date()
            current_time = datetime.now(bst)
            current_time = current_time.strftime('%I:%M:%S %p')

            #book title
            try:
                title = books_header_1.find("h1")
                book_title = title.contents[0].strip()
            except AttributeError:
                book_title = ""
                pass
            #book author name
            try:
                book_author = main_header_1.find("p",class_="details-book-info__content-author").find("a").text.strip()
            except AttributeError:
                book_author = ""
                pass
            #category name
            try:
                category = main_header_1.find("div",class_="details-book-info__content-category d-flex align-items-center").find("a").text.strip()
            except AttributeError:
                category = ""
                pass
            #original price
            try:
                original_price_div = main_header_1.find("div", class_="details-book-info__content-book-price")
                if original_price_div and original_price_div.find("strike"):
                    #original price exists, so extract the text
                    original_price = original_price_div.find("strike").text.strip()
                else:
                    #original price does not exist
                    original_price = ""  #or set it to some default value
            except  AttributeError:
                original_price = ""
                pass
            #sell price
            try:
                sell_price = main_header_1.find("span",class_="sell-price").text.strip()
            except AttributeError:
                sell_price = ""
                pass
            #discount amount
            try:
                discount_div = main_header_1.find("div", class_="details-book-info__content-book-price")
                if discount_div and discount_div.find("span",class_="js--save-message"):
                    discount = discount_div.find(class_="js--save-message").text.strip()
                else:
                    discount = ""  #or set it to some default value
            except AttributeError:
                discount = ""
                pass
            #best selller badge
            try:
                best_seller_merit_div = main_header_1.find("p",class_="best-seller-badge")
                if best_seller_merit_div:
                    best_seller_merit = best_seller_merit_div.find("span").text.strip()
                else:
                    best_seller_merit = ""
                    
            except AttributeError:
                best_seller_merit = ""
                pass        
            #ebook availability
            try:
                ebook_availability_ensure = main_header_1.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_availability = "Yes"
                else:
                    ebook_availability = "No"
            except AttributeError:
                ebook_availability = "No"
                pass
            #ebook price
            try:
                ebook_availability_ensure = main_header_1.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_price = ebook_availability_ensure.find("p",class_="ebook-price").text.strip()
                else:
                    ebook_price = ""
            except AttributeError:
                ebook_price = ""
                pass   
            #ratings count
            try:
                ratings_reviwe = main_header_1.find("div", class_="details-book-info__content-rating").find("span", "ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                # Extract ratings count
                ratings_count = ratings_text.strip().split()[0]
            except AttributeError:
                ratings_count = ""
                pass
            #reviews count
            try:
                ratings_reviwe = main_header_1.find("div", class_="details-book-info__content-rating").find("span", "ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                reviews_count = reviews_text.strip().split()[0]
            except AttributeError:
                reviews_count = ""
                pass
            #ratings
            try:
                rating = book_soup_prettify.find("div",class_="review-wrapper__rating-summary").find("h3",class_="summary-title").text.strip()
            except AttributeError:
                rating = ""
                pass        
            #publisher name
            try:          
                publisher_name_info = additional_info_1.find("table",class_="table table-bordered")
                if publisher_name_info and publisher_name_info.find("td",class_="publisher-link").find("a"):
                    publisher_name = publisher_name_info.find("td",class_="publisher-link").find("a").text.strip()
                else:
                    publisher_name = ""
            except AttributeError:
                publisher_name = ""
            #country name
            try:
                country_name_infos = additional_info_1.find_all("td")
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Country":
                        c_name = country_name_info.find_next_sibling("td")
                        country_name = c_name.get_text(strip=True)
                        break
                    else:
                        country_name = ""
                        continue
            except AttributeError:
                country_name = ""
                pass
            #language information
            try:
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Language":
                        l_name = country_name_info.find_next_sibling("td")
                        language_name = l_name.get_text(strip=True)
                        break
                    else:
                        language_name = ""
                        continue
            except AttributeError:
                language_name = ""
                pass
            #add the extracted data to the worksheet
            row_data = [current_date, current_time, book_title, book_author, category, original_price, sell_price, discount, best_seller_merit, ebook_availability, ebook_price, ratings_count,
                        reviews_count, rating, publisher_name, language_name, country_name,page_number]
            ws.append(row_data)
               
            print(f"Information of {book_title}: {page_number}\n\n")
            print("Current Date:", current_date)
            print("Current Time:", current_time)
            print(f"Book Title:{book_title}")
            print(f"Book Author Name:{book_author}")
            print(f"Book Catagory:{category}")
            print(f"Original Price:{original_price} tk")
            print(f"Sell Price:{sell_price} tk")
            print(f"Discount Rate:{discount}")
            print(f"Best seller merit:{best_seller_merit}")
            print(f"E-book availability:{ebook_availability}")
            print(f"E-book price:{ebook_price}")
            print(f"Total Ratings:{ratings_count}")
            print(f"Total Review:{reviews_count}")
            print(f"Ratings:{rating}")
            print(f"Publication name:{publisher_name}")
            print(f"Language:{language_name}")
            print(f"Country name:{country_name}")
            print(saved)
            wb.save(saved)
            print(f"-----------------\n\n") 
            
        elif main_header_2 and books_header_2:

            current_date = datetime.now().date()
            current_time = datetime.now(bst)
            current_time = current_time.strftime('%I:%M:%S %p')
            
            #book name
            try:
                title = books_header_2.find("h1", class_="title mb-0")
                book_title = title.contents[0].strip()
            except AttributeError:
                book_title = ""
                pass          
            #author name
            try:
                book_author = main_header_2.find("p", class_="details-stationary__brand").find("a").text.strip()
            except AttributeError:
                book_author = ""
                pass     
            #category name
            try:
                category = main_header_2.find("p", class_="details-stationary__category").find("a").text.strip()
            except AttributeError:
                category = ""
                pass            
            #original price
            try:
                original_price_div = main_header_2.find("div", class_="details-stationary__price")
                if original_price_div and original_price_div.find("strike"):
                    original_price = original_price_div.find("strike").text.strip()
                else:
                    original_price = ""
            except AttributeError:
                original_price = ""
                pass            
            #sell price
            try:
                sell_price = main_header_2.find("span", class_="sell-price").text.strip()
            except AttributeError:
                sell_price = ""
                pass           
            #discount rate
            try:
                discount_div = main_header_2.find("div", class_="details-stationary__price")
                if discount_div and discount_div.find("span", class_="js--save-message"):
                    discount = discount_div.find(class_="js--save-message").text.strip()
                else:
                    discount = ""
            except AttributeError:
                discount = ""
                pass

            #best selller badge
            try:
                best_seller_merit_div = main_header_2.find("p",class_="best-seller-badge")
                if best_seller_merit_div:
                    best_seller_merit = best_seller_merit_div.find("span").text.strip()
                else:
                    best_seller_merit = ""
                    
            except AttributeError:
                best_seller_merit = ""
                pass
            #ebook availability
            try:
                ebook_availability_ensure = main_header_2.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_availability = "Yes"
                else:
                    ebook_availability = "No"
            except AttributeError:
                ebook_availability = "No"
                pass
            #ebook price
            try:
                ebook_availability_ensure = main_header_2.find("div",class_="ebook-buy-now d-flex align-items-center")
                if ebook_availability_ensure:
                    ebook_price = ebook_availability_ensure.find("p",class_="ebook-price").text.strip()
                else:
                    ebook_price = ""
            except AttributeError:
                ebook_price = ""
                pass          
            #rating count
            try:
                ratings_reviwe = main_header_2.find("div", class_="details-stationary__stars").find("span", class_="ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                # Extract ratings count
                ratings_count = ratings_text.strip().split()[0]
            except AttributeError:
                ratings_count = ""
                pass
            #reviews count
            try:
                ratings_reviwe = main_header_2.find("div", class_="details-stationary__stars").find("span", class_="ml-2").text.strip()
                ratings_text, reviews_text = ratings_reviwe.split('|')
                reviews_count = reviews_text.strip().split()[0]
            except AttributeError:
                reviews_count = ""
                pass

            #ratings
            try:
                rating = book_soup_prettify.find("div",class_="details-ratings-review__rating-summary").find("h3",class_="summary-title").text.strip()
            except AttributeError:
                rating = ""
                pass
            #publisher name
            try:
                publisher_infos = additional_info_2.find_all("td", class_="proDetailValue")
                for publisher_info in publisher_infos:
                    if publisher_info.find("a"):
                        publisher_name = publisher_info.find("a").text.strip()
                        break
                else:
                    publisher_name = ""
            except AttributeError:
                publisher_name = ""
                pass          
            #country name
            try:
                country_name_infos = additional_info_2.find_all("td")
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() ==  "Country of Origin":
                        c_name = country_name_info.find_next_sibling("td")
                        country_name = c_name.get_text(strip=True)
                        break
                else:
                    country_name = ""
            except AttributeError:
                country_name = ""
                pass          
            #language name
            try:
                for country_name_info in country_name_infos:
                    if country_name_info.text.strip() == "Version":
                        l_name = country_name_info.find_next_sibling("td")
                        language_name = l_name.get_text(strip=True)
                        break
                else:
                    language_name = ""
            except AttributeError:
                language_name = ""
                pass

            #add the extracted data to the worksheet
            row_data = [current_date, current_time, book_title, book_author, category, original_price, sell_price, discount, best_seller_merit, ebook_availability, ebook_price, ratings_count,
                        reviews_count, rating, publisher_name, language_name, country_name,page_number]
            ws.append(row_data)
            
            print(f"Information of {book_title}: {page_number}\n\n")
            print("Current Date:", current_date)
            print("Current Time:", current_time)
            print(f"Book Title:{book_title}")
            print(f"Book Author Name:{book_author}")
            print(f"Book Catagory:{category}")
            print(f"Original Price:{original_price} tk")
            print(f"Sell Price:{sell_price} tk")
            print(f"Discount Rate:{discount}")
            print(f"Best seller merit:{best_seller_merit}")
            print(f"E-book availability:{ebook_availability}")
            print(f"E-book price:{ebook_price}")
            print(f"Total Ratings:{ratings_count}")
            print(f"Total Review:{reviews_count}")
            print(f"Ratings:{rating}")
            print(f"Publication name:{publisher_name}")
            print(f"Language:{language_name}")
            print(f"Country name:{country_name}")
            print(saved)
            wb.save(saved)
            print("-----------------\n\n")
            
        else:
            print("Book title not found for:", full_link)
            continue

    #save the workbook
    # wb.save("C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_books_informations2.xlsx")
    print(f"\n\n---------------data is loaded of {page_number}---------\n\n")
    page_number = page_number + 1
    
#save the workbook
# wb.save("C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_books_informations2.xlsx")
print(f"Total loaded page {page_number}")
# Out:
# ---------------data is loading from 101---------
#
#
# Information of Perfumance Dunhil Red (ডানহিল রেড) - 14.5 ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:25 PM
# Book Title:Perfumance Dunhil Red (ডানহিল রেড) - 14.5 ml
# Book Author Name:Perfumance
# Book Catagory:Attar
# Original Price:TK. 360 tk
# Sell Price:TK. 324 tk
# Discount Rate:You Save TK. 36 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Perfumance
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Al-Iman Turkey Prayer Jaynamaz - (জায়নামাজ) Green Color (Any design): 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:26 PM
# Book Title:Al-Iman Turkey Prayer Jaynamaz - (জায়নামাজ) Green Color (Any design)
# Book Author Name:Al-Iman
# Book Catagory:Jaynamaz
# Original Price:TK. 770 tk
# Sell Price:TK. 693 tk
# Discount Rate:You Save TK. 77 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Al-Iman
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Safa Tex Muslim Prayer Jaynamaz -জায়নামাজ (White) - Any Design: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:27 PM
# Book Title:Safa Tex Muslim Prayer Jaynamaz -জায়নামাজ (White) - Any Design
# Book Author Name:Safa Teks
# Book Catagory:Jaynamaz
# Original Price:TK. 1,420 tk
# Sell Price:TK. 1,278 tk
# Discount Rate:You Save TK. 142 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Safa Teks
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Savlon Hand Wash Ocen Blue 5 Litre (Bottle) - AN93: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:28 PM
# Book Title:Savlon Hand Wash Ocen Blue 5 Litre (Bottle) - AN93
# Book Author Name:Savlon
# Book Catagory:Hand wash
# Original Price: tk
# Sell Price:TK. 1,350 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Savlon
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Meril Petroleum Jelly New Aloevera 50 ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:29 PM
# Book Title:Meril Petroleum Jelly New Aloevera 50 ml
# Book Author Name:Meril
# Book Catagory:Lotion, Cream
# Original Price: tk
# Sell Price:TK. 80 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:5.0
# Publication name:Meril
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Jui Pure Cocoanut Oil (Tin) 350 ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:30 PM
# Book Title:Jui Pure Cocoanut Oil (Tin) 350 ml
# Book Author Name:Jui
# Book Catagory:Hair Oils
# Original Price: tk
# Sell Price:TK. 255 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Jui
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Wiwu 14 inch Pilot Sleeve Laptop Bag- Grey: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:31 PM
# Book Title:Wiwu 14 inch Pilot Sleeve Laptop Bag- Grey
# Book Author Name:Wiwu
# Book Catagory:Laptop Cases & Sleeves
# Original Price:TK. 2,000 tk
# Sell Price:TK. 1,599 tk
# Discount Rate:You Save TK. 401 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Wiwu
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Tomica Regular Diecast No. 082-08 Toyota Sora - 158448: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:33 PM
# Book Title:Tomica Regular Diecast No. 082-08 Toyota Sora - 158448
# Book Author Name:Takara Tomy
# Book Catagory:Die-Cast Vehicle
# Original Price: tk
# Sell Price:TK. 590 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Takara Tomy
# Language:
# Country name:Vietnam
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Olivita Extra Virgin Olive Oil Glass Bottle 250ml (Spain) - 131700874: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:34 PM
# Book Title:Olivita Extra Virgin Olive Oil Glass Bottle 250ml (Spain) - 131700874
# Book Author Name:Olivita
# Book Catagory:Olive Oil
# Original Price:TK. 304 tk
# Sell Price:TK. 264 tk
# Discount Rate:You Save TK. 40 (13%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Olivita
# Language:
# Country name:Spain
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Spine Lumbar Roll Cushion for Lower Back Pain, Car Seat And Office Chair: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:34 PM
# Book Title:Spine Lumbar Roll Cushion for Lower Back Pain, Car Seat And Office Chair
# Book Author Name:Non-Brand
# Book Catagory:Health Accessories
# Original Price: tk
# Sell Price:TK. 250 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of M and G Stick Gel Pen Black Ink (0.7mm) - (1Pcs) AGPB4271: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:36 PM
# Book Title:M and G Stick Gel Pen Black Ink (0.7mm) - (1Pcs) AGPB4271
# Book Author Name:M&G
# Book Catagory:Gel pen
# Original Price: tk
# Sell Price:TK. 113 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:M&G
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/312320/remax-rm-588-cheap-3-5mm-wired-in-ear-sleep-earphone
# Information of HOT WHEELS Regular - Toyota Off-Road Truck - Orange: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:38 PM
# Book Title:HOT WHEELS Regular - Toyota Off-Road Truck - Orange
# Book Author Name:Hot Wheels (Collector's Edition)
# Book Catagory:Die-Cast Vehicle
# Original Price: tk
# Sell Price:TK. 290 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hot Wheels (Collector's Edition)
# Language:
# Country name:Malaysia
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/186093/havit-wired-headphone-h2198d
# Information of Shashya Prabartana Chickpea Flour (বেসন) - 1 kg: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:40 PM
# Book Title:Shashya Prabartana Chickpea Flour (বেসন) - 1 kg
# Book Author Name:Shashya Prabartana
# Book Catagory:Grain food
# Original Price: tk
# Sell Price:TK. 160 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:4.0
# Publication name:Shashya Prabartana
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Sundrop Peanut Butter Creamy (পিনাট বাটার ক্রিম) (462 gm) - AI22: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:40 PM
# Book Title:Sundrop Peanut Butter Creamy (পিনাট বাটার ক্রিম) (462 gm) - AI22
# Book Author Name:Sundrop
# Book Catagory:Butter
# Original Price: tk
# Sell Price:TK. 560 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Sundrop
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mama Instant Cup Noodles Shrimp Tom Yum Extreme Flavour (60 gm) - M145070: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:42 PM
# Book Title:Mama Instant Cup Noodles Shrimp Tom Yum Extreme Flavour (60 gm) - M145070
# Book Author Name:Mama
# Book Catagory:Noodles
# Original Price: tk
# Sell Price:TK. 180 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mama
# Language:
# Country name:Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Premium Colour Pencils 36pc - MPN0112: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:43 PM
# Book Title:Mont Marte Premium Colour Pencils 36pc - MPN0112
# Book Author Name:Mont Marte
# Book Catagory:Pencil
# Original Price: tk
# Sell Price:TK. 1,750 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Safa Teks Turkey Prayer Mat Mihrab Jaynamaz-জায়নামাজ - Green Color-Any Design: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:44 PM
# Book Title:Safa Teks Turkey Prayer Mat Mihrab Jaynamaz-জায়নামাজ - Green Color-Any Design
# Book Author Name:Safa Teks
# Book Catagory:Jaynamaz
# Original Price:TK. 1,214 tk
# Sell Price:TK. 1,093 tk
# Discount Rate:You Save TK. 121 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Safa Teks
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Green Grocery Gawa Ghee (গাওয়া ঘি) - 330 gm: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:45 PM
# Book Title:Green Grocery Gawa Ghee (গাওয়া ঘি) - 330 gm
# Book Author Name:Green Grocery
# Book Catagory:Ghee
# Original Price: tk
# Sell Price:TK. 590 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Green Grocery
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Meril Baby Gel Toothpaste with Strawberry Flavor - 45 gm - M-101-98194: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:46 PM
# Book Title:Meril Baby Gel Toothpaste with Strawberry Flavor - 45 gm - M-101-98194
# Book Author Name:Meril
# Book Catagory:Baby Toothpastes
# Original Price: tk
# Sell Price:TK. 90 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Meril
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Neem Original Nourishing Hand Wash CN04 200 ml - CN04: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:48 PM
# Book Title:Neem Original Nourishing Hand Wash CN04 200 ml - CN04
# Book Author Name:Neem Original
# Book Catagory:Hand wash
# Original Price: tk
# Sell Price:TK. 75 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Neem Original
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Skin Tints Coloured Pencils 12pcs - MPN0103: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:51 PM
# Book Title:Mont Marte Skin Tints Coloured Pencils 12pcs - MPN0103
# Book Author Name:Mont Marte
# Book Catagory:Pencil
# Original Price:TK. 420 tk
# Sell Price:TK. 350 tk
# Discount Rate:You Save TK. 70 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Azan Lifestyle Bakhoor Al Arais Attar - 4.25ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:54 PM
# Book Title:Azan Lifestyle Bakhoor Al Arais Attar - 4.25ml
# Book Author Name:Azan Lifestyle
# Book Catagory:Attar
# Original Price: tk
# Sell Price:TK. 245 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Azan Lifestyle
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Fine Tip Markers, Vibrant Colors with 0.4mm Fine Line Point - 12 Colour Box: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:56 PM
# Book Title:Mont Marte Fine Tip Markers, Vibrant Colors with 0.4mm Fine Line Point - 12 Colour Box
# Book Author Name:Mont Marte
# Book Catagory:Textliner and Highlighter
# Original Price: tk
# Sell Price:TK. 420 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of SREEZON Premium Hugo (হুগো) Attar - 3 ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:56:58 PM
# Book Title:SREEZON Premium Hugo (হুগো) Attar - 3 ml
# Book Author Name:SREEZON
# Book Catagory:Attar
# Original Price:TK. 160 tk
# Sell Price:TK. 144 tk
# Discount Rate:You Save TK. 16 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:3
# Total Review:No
# Ratings:5.0
# Publication name:SREEZON
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/183764/adata-power-bank-x7000
# Information of Mumtaz Neem Oil (Nimer Tel) - 60ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:02 PM
# Book Title:Mumtaz Neem Oil (Nimer Tel) - 60ml
# Book Author Name:Mumtaz Herbal Products
# Book Catagory:Herbal Hair Care
# Original Price: tk
# Sell Price:TK. 150 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mumtaz Herbal Products
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Masjid Comfort Jaynamaz for Prayer - Maroon Color (Any design): 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:06 PM
# Book Title:Masjid Comfort Jaynamaz for Prayer - Maroon Color (Any design)
# Book Author Name:Al-Muslim
# Book Catagory:Jaynamaz
# Original Price:TK. 486 tk
# Sell Price:TK. 437 tk
# Discount Rate:You Save TK. 49 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Al-Muslim
# Language:
# Country name:Turkey
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Cute Mini Highlighter Box 6Pcs: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:08 PM
# Book Title:Cute Mini Highlighter Box 6Pcs
# Book Author Name:Non-Brand
# Book Catagory:Stationery Collection
# Original Price: tk
# Sell Price:TK. 199 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Pretend Play Plastic Food Toy Cutting Fruit Vegetable Food Pretend Play Children Kids Birthday Gift - Baby Toys: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:09 PM
# Book Title:Pretend Play Plastic Food Toy Cutting Fruit Vegetable Food Pretend Play Children Kids Birthday Gift - Baby Toys
# Book Author Name:Non-Brand
# Book Catagory:Baby & Toddler Toys
# Original Price: tk
# Sell Price:TK. 870 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:Abroad
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Hot Wheels Regular – 21 Ford Bronco 1/5 and 68/250: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:10 PM
# Book Title:Hot Wheels Regular – 21 Ford Bronco 1/5 and 68/250
# Book Author Name:Hot Wheels (Collector's Edition)
# Book Catagory:Die-Cast Vehicle
# Original Price: tk
# Sell Price:TK. 290 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hot Wheels (Collector's Edition)
# Language:
# Country name:Malaysia
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/187668/rapoo-power-bank-10000-mah
# Book title not found for: https://www.rokomari.com/electronics/186090/havit-gaming-wired-headphone-h2239d
# Information of Olay Day Cream Natural White Moisturiser SPF 24- 50g - OO0152: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:16 PM
# Book Title:Olay Day Cream Natural White Moisturiser SPF 24- 50g - OO0152
# Book Author Name:Olay
# Book Catagory:Moisturizers & Cream
# Original Price: tk
# Sell Price:TK. 650 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Olay
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of SMS Smile Belt System Baby Diaper (Size-XL) (11-18kg) (22Pcs): 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:17 PM
# Book Title:SMS Smile Belt System Baby Diaper (Size-XL) (11-18kg) (22Pcs)
# Book Author Name:Smile Baby Diaper
# Book Catagory:Baby Disposable Diapers
# Original Price:TK. 620 tk
# Sell Price:TK. 479 tk
# Discount Rate:You Save TK. 141 (23%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Smile Baby Diaper
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of JackKevin Men's Backpack Water Proof Laptop Bag School Bags Collage Bag Sports Travel Bag USB Charging Backpacks: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:19 PM
# Book Title:JackKevin Men's Backpack Water Proof Laptop Bag School Bags Collage Bag Sports Travel Bag USB Charging Backpacks
# Book Author Name:Non-Brand
# Book Catagory:Backpacks
# Original Price:TK. 680 tk
# Sell Price:TK. 599 tk
# Discount Rate:You Save TK. 81 (12%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:2
# Total Review:No
# Ratings:2.0
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Hot Wheels Regular – Range Rover Classic – 4/5 – 159/250 – light Green: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:20 PM
# Book Title:Hot Wheels Regular – Range Rover Classic – 4/5 – 159/250 – light Green
# Book Author Name:Hot Wheels (Collector's Edition)
# Book Catagory:Die-Cast Vehicle
# Original Price: tk
# Sell Price:TK. 440 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hot Wheels (Collector's Edition)
# Language:
# Country name:Malaysia
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Olay Night Cream: Natural White 7 in 1 Night Cream 50gm - OO0151: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:22 PM
# Book Title:Olay Night Cream: Natural White 7 in 1 Night Cream 50gm - OO0151
# Book Author Name:Olay
# Book Catagory:Moisturizers & Cream
# Original Price: tk
# Sell Price:TK. 650 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:1.0
# Publication name:Olay
# Language:
# Country name:Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Meshcah Premium Muslim Prayer Jaynamaz-জায়নামাজ (Black and Mixed Color) - Any Design: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:24 PM
# Book Title:Meshcah Premium Muslim Prayer Jaynamaz-জায়নামাজ (Black and Mixed Color) - Any Design
# Book Author Name:Mada Carpets
# Book Catagory:Jaynamaz
# Original Price:TK. 3,571 tk
# Sell Price:TK. 3,214 tk
# Discount Rate:You Save TK. 357 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mada Carpets
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Fabrilife Premium 7 Layer Hazel Womens Designer Edition Mask: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:26 PM
# Book Title:Fabrilife Premium 7 Layer Hazel Womens Designer Edition Mask
# Book Author Name:Fabrilife
# Book Catagory:Protective Face Mask
# Original Price:TK. 370 tk
# Sell Price:TK. 290 tk
# Discount Rate:You Save TK. 80 (22%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Fabrilife
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mumtaz Henna Mehndi Pack - (3X20gm = 60gm): 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:27 PM
# Book Title:Mumtaz Henna Mehndi Pack - (3X20gm = 60gm)
# Book Author Name:Mumtaz Herbal Products
# Book Catagory:Herbal Hair Care
# Original Price: tk
# Sell Price:TK. 90 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mumtaz Herbal Products
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Helicon Quick Dry Correction Pen - 2 Pcs: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:28 PM
# Book Title:Helicon Quick Dry Correction Pen - 2 Pcs
# Book Author Name:Non-Brand
# Book Catagory:Stationery Collection
# Original Price: tk
# Sell Price:TK. 130 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Kartal Deluxe Artistic Set Wooden Box Drawing Set For Kids Crafts Kit Box Gift, Painting And more Set of 150 Pieces: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:30 PM
# Book Title:Kartal Deluxe Artistic Set Wooden Box Drawing Set For Kids Crafts Kit Box Gift, Painting And more Set of 150 Pieces
# Book Author Name:Non-Brand
# Book Catagory:Arts Sets
# Original Price: tk
# Sell Price:TK. 1,750 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/265518/anker-powercore-select-10000mah-power-bank-black
# Information of Fabrilife Premium 5 Layer Yale Kids Designer Edition Cotton Mask: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:33 PM
# Book Title:Fabrilife Premium 5 Layer Yale Kids Designer Edition Cotton Mask
# Book Author Name:Fabrilife
# Book Catagory:Protective Face Mask
# Original Price:TK. 300 tk
# Sell Price:TK. 220 tk
# Discount Rate:You Save TK. 80 (27%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Fabrilife
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/330846/baseus-star-lord-30000mah-22-5w-power-bank
# Information of Man Matters Minoxidil 5percent plus 0.1percent Finasteride Topical Solution - Minoxifin 60ml: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:35 PM
# Book Title:Man Matters Minoxidil 5percent plus 0.1percent Finasteride Topical Solution - Minoxifin 60ml
# Book Author Name:Man matters
# Book Catagory:Processing: Product
# Original Price:TK. 1,790 tk
# Sell Price:TK. 1,485 tk
# Discount Rate:You Save TK. 305 (17%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Man matters
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Baby Stroller C3 Pram for Your Baby with Rocking Mood and Adjustable Handle Bar Best Premium Quality Prams Trolly- Magenta: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:37 PM
# Book Title:Baby Stroller C3 Pram for Your Baby with Rocking Mood and Adjustable Handle Bar Best Premium Quality Prams Trolly- Magenta
# Book Author Name:Non-Brand
# Book Catagory:Baby Strollers & Prams
# Original Price: tk
# Sell Price:TK. 9,900 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Panash Food Neem Powder (Neem Gura) - 100 gm: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:39 PM
# Book Title:Panash Food Neem Powder (Neem Gura) - 100 gm
# Book Author Name:Panash Food
# Book Catagory:Functional Food
# Original Price:TK. 90 tk
# Sell Price:TK. 86 tk
# Discount Rate:You Save TK. 4 (4%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Panash Food
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Foot Massage Slippers Reflexology Health Acupuncture Health Shoes Slipper Healthy Massager Pebble Feet - Body Massager: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:40 PM
# Book Title:Foot Massage Slippers Reflexology Health Acupuncture Health Shoes Slipper Healthy Massager Pebble Feet - Body Massager
# Book Author Name:Non-Brand
# Book Catagory:Foot Relief Accessories & Tools
# Original Price: tk
# Sell Price:TK. 663 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Book title not found for: https://www.rokomari.com/electronics/330788/usams-us-cd186-pb69-10000mah-digital-display-power-bank-with-lanyard
# Book title not found for: https://www.rokomari.com/electronics/247600/philips-bhc015-05-essential-care-hair-dryer
# Information of The Derma Co 1percent Hyaluronic Tinted Sunscreen Gel For Broad Spectrum Protection SPF 60 - 50g: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:44 PM
# Book Title:The Derma Co 1percent Hyaluronic Tinted Sunscreen Gel For Broad Spectrum Protection SPF 60 - 50g
# Book Author Name:The derma co
# Book Catagory:Processing: Product
# Original Price:TK. 1,600 tk
# Sell Price:TK. 1,285 tk
# Discount Rate:You Save TK. 315 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:The derma co
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Noor Jahan Rehal: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:46 PM
# Book Title:Noor Jahan Rehal
# Book Author Name:Non-Brand
# Book Catagory:Rehal
# Original Price:TK. 160 tk
# Sell Price:TK. 144 tk
# Discount Rate:You Save TK. 16 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Sports Stainless Steel Water Bottle 800 ml for Men Women Kids Thermos Flask Reusable Leak-Proof Thermosteel for Home Office Gym Fridge Travelling (0.8 Liters): 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:47 PM
# Book Title:Sports Stainless Steel Water Bottle 800 ml for Men Women Kids Thermos Flask Reusable Leak-Proof Thermosteel for Home Office Gym Fridge Travelling (0.8 Liters)
# Book Author Name:Non-Brand
# Book Catagory:Thermal Flask
# Original Price: tk
# Sell Price:TK. 850 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Bangabandhu - Miniature Replica: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:48 PM
# Book Title:Bangabandhu - Miniature Replica
# Book Author Name:Hat Bakso
# Book Catagory:Showpiece
# Original Price: tk
# Sell Price:TK. 1,700 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hat Bakso
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of পাশা - এএএএএএএ (মারজুক রাসেলের টি-শার্ট) - Olive - XXL: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:50 PM
# Book Title:পাশা - এএএএএএএ (মারজুক রাসেলের টি-শার্ট) - Olive - XXL
# Book Author Name:Golla
# Book Catagory:T-shirt
# Original Price: tk
# Sell Price:TK. 400 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Golla
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Deli Fingertip Roller Moistener - E9109: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:52 PM
# Book Title:Deli Fingertip Roller Moistener - E9109
# Book Author Name:Non-Brand
# Book Catagory:Desk Organizers
# Original Price: tk
# Sell Price:TK. 150 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Clay Jug - CJ-03-NC: 101
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:54 PM
# Book Title:Clay Jug - CJ-03-NC
# Book Author Name:Bhola Mritshilpa
# Book Catagory:Jugs & Pitchers
# Original Price: tk
# Sell Price:TK. 450 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Bhola Mritshilpa
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
#
#
# ---------------data is loaded of 101---------
#
#
# ---------------data is loading from 102---------
#
#
# Information of DDecorator Vikings Laptop Sticker - (LSKN691): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:56 PM
# Book Title:DDecorator Vikings Laptop Sticker - (LSKN691)
# Book Author Name:DDecorator
# Book Catagory:Laptop Sticker
# Original Price: tk
# Sell Price:TK. 257 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:DDecorator
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Strip Stapler - E0425: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:57 PM
# Book Title:Strip Stapler - E0425
# Book Author Name:Deli
# Book Catagory:Stapler and Punch machine
# Original Price: tk
# Sell Price:TK. 150 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Deli
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Canvas Paper- A3 10pcs: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:57:59 PM
# Book Title:Canvas Paper- A3 10pcs
# Book Author Name:Ahbab
# Book Catagory:Canvas
# Original Price: tk
# Sell Price:TK. 264 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:1
# Ratings:5.0
# Publication name:Ahbab
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Round Canvas 4 inch: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:00 PM
# Book Title:Round Canvas 4 inch
# Book Author Name:Ahbab
# Book Catagory:Canvas
# Original Price: tk
# Sell Price:TK. 99 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Ahbab
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Canvas Square 16x20 Inch: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:02 PM
# Book Title:Canvas Square 16x20 Inch
# Book Author Name:Iconic Sourcing
# Book Catagory:Canvas
# Original Price: tk
# Sell Price:TK. 180 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Iconic Sourcing
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Foldable Jaynamaz - Maroon: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:03 PM
# Book Title:Foldable Jaynamaz - Maroon
# Book Author Name:Al-Arabia
# Book Catagory:Islamic Accessories
# Original Price:TK. 2,000 tk
# Sell Price:TK. 1,800 tk
# Discount Rate:You Save TK. 200 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:5.0
# Publication name:Al-Arabia
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Vega Bolt Black Helmet: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:04 PM
# Book Title:Vega Bolt Black Helmet
# Book Author Name:VEGA
# Book Catagory:Helmet
# Original Price:TK. 2,800 tk
# Sell Price:TK. 2,400 tk
# Discount Rate:You Save TK. 400 (14%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:1
# Total Review:No
# Ratings:4.0
# Publication name:VEGA
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Magnetic Dart Board - Small: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:06 PM
# Book Title:Magnetic Dart Board - Small
# Book Author Name:Non-Brand
# Book Catagory:Board Games
# Original Price: tk
# Sell Price:TK. 900 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:N/A
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Afdal Dehnal Oud Nakki - 3gm: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:07 PM
# Book Title:Afdal Dehnal Oud Nakki - 3gm
# Book Author Name:Afdal
# Book Catagory:Attar
# Original Price:TK. 1,700 tk
# Sell Price:TK. 1,530 tk
# Discount Rate:You Save TK. 170 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Afdal
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of SAMS Mini Calculator - SX 300 e: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:08 PM
# Book Title:SAMS Mini Calculator - SX 300 e
# Book Author Name:SAMS
# Book Catagory:Desk Calculator
# Original Price: tk
# Sell Price:TK. 300 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:SAMS
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of DDecorator Cute Cat Laptop Sticker - (LS186): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:09 PM
# Book Title:DDecorator Cute Cat Laptop Sticker - (LS186)
# Book Author Name:DDecorator
# Book Catagory:Laptop Sticker
# Original Price: tk
# Sell Price:TK. 125 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:DDecorator
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Kores Carbon Paper 10 Pcs: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:11 PM
# Book Title:Kores Carbon Paper 10 Pcs
# Book Author Name:Non-Brand
# Book Catagory:Painting, Drawing & Art Supplies
# Original Price:TK. 60 tk
# Sell Price:TK. 51 tk
# Discount Rate:You Save TK. 9 (15%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Haldiram Bhujia Spicy - 200gm: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:13 PM
# Book Title:Haldiram Bhujia Spicy - 200gm
# Book Author Name:Haldiram
# Book Catagory:Local Snacks
# Original Price:TK. 275 tk
# Sell Price:TK. 248 tk
# Discount Rate:You Save TK. 27 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Haldiram
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Ermani Air Freshener Lemon - 180gm - Air Fresh (Lemo): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:14 PM
# Book Title:Ermani Air Freshener Lemon - 180gm - Air Fresh (Lemo)
# Book Author Name:Ermani
# Book Catagory:Air freshener
# Original Price:TK. 240 tk
# Sell Price:TK. 211 tk
# Discount Rate:You Save TK. 29 (12%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Ermani
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Hearts Travelers Drawing Book: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:15 PM
# Book Title:Hearts Travelers Drawing Book
# Book Author Name:Hearts Bangladesh
# Book Catagory:Drawing book
# Original Price: tk
# Sell Price:TK. 124 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hearts Bangladesh
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Canvas Square 12inch by 18inch: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:17 PM
# Book Title:Canvas Square 12inch by 18inch
# Book Author Name:Iconic Sourcing
# Book Catagory:Canvas
# Original Price: tk
# Sell Price:TK. 155 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Iconic Sourcing
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Deli White Glue - 40 ml: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:18 PM
# Book Title:Deli White Glue - 40 ml
# Book Author Name:Deli
# Book Catagory:Adhesive, Gum and Glue stick
# Original Price: tk
# Sell Price:TK. 150 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Deli
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Escape Fifa 2022 Backpack - M-106: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:21 PM
# Book Title:Escape Fifa 2022 Backpack - M-106
# Book Author Name:ESCAPE
# Book Catagory:Backpacks
# Original Price:TK. 800 tk
# Sell Price:TK. 680 tk
# Discount Rate:You Save TK. 120 (15%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:ESCAPE
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Canvas for Painting 24/36: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:22 PM
# Book Title:Canvas for Painting 24/36
# Book Author Name:Non-Brand
# Book Catagory:Canvas
# Original Price: tk
# Sell Price:TK. 250 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Flamingo Windshield Washer-500 ML: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:23 PM
# Book Title:Flamingo Windshield Washer-500 ML
# Book Author Name:Flamingo
# Book Catagory:Cleaners and Kits
# Original Price:TK. 450 tk
# Sell Price:TK. 320 tk
# Discount Rate:You Save TK. 130 (29%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Flamingo
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Kangaro Stapler HD-1213: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:25 PM
# Book Title:Kangaro Stapler HD-1213
# Book Author Name:Kangaro
# Book Catagory:Stapler and Punch machine
# Original Price: tk
# Sell Price:TK. 2,100 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Kangaro
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Domes Neon Rubber Tipped Graphite Pencils: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:26 PM
# Book Title:Domes Neon Rubber Tipped Graphite Pencils
# Book Author Name:Doms
# Book Catagory:Pencil
# Original Price: tk
# Sell Price:TK. 80 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Doms
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Puzzle blocks ( Any Color ): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:28 PM
# Book Title:Puzzle blocks ( Any Color )
# Book Author Name:Non-Brand
# Book Catagory:Puzzle & Cubes
# Original Price: tk
# Sell Price:TK. 400 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Shaheed Minar (Multicolor) - Fridge Magnet: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:30 PM
# Book Title:Shaheed Minar (Multicolor) - Fridge Magnet
# Book Author Name:Hat Bakso
# Book Catagory:Fridge Sticker & Decals
# Original Price: tk
# Sell Price:TK. 400 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hat Bakso
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of DDecorator Seamless geometry pattern laptop sticker - LSKN2425: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:31 PM
# Book Title:DDecorator Seamless geometry pattern laptop sticker - LSKN2425
# Book Author Name:DDecorator
# Book Catagory:Laptop Sticker
# Original Price: tk
# Sell Price:TK. 257 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:DDecorator
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of DDecorator Save Energy Switch Wall Sticker - (SS196): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:33 PM
# Book Title:DDecorator Save Energy Switch Wall Sticker - (SS196)
# Book Author Name:DDecorator
# Book Catagory:Socket sticker
# Original Price:TK. 171 tk
# Sell Price:TK. 162 tk
# Discount Rate:You Save TK. 9 (5%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:DDecorator
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Flat Brush- 1.5 inch: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:34 PM
# Book Title:Flat Brush- 1.5 inch
# Book Author Name:Non-Brand
# Book Catagory:Artist Brushes & Tools
# Original Price: tk
# Sell Price:TK. 154 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Hearts Smart Shopping Bags Yellow (Large): 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:36 PM
# Book Title:Hearts Smart Shopping Bags Yellow (Large)
# Book Author Name:Hearts Bangladesh
# Book Catagory:Gift Bag
# Original Price: tk
# Sell Price:TK. 108 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Hearts Bangladesh
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Meiji Yan Yan Choco 50gm: 102
#
#
# Current Date: 2024-04-19
# Current Time: 01:58:37 PM
# Book Title:Meiji Yan Yan Choco 50gm
# Book Author Name:Meiji
# Book Catagory:Chocolate
# Original Price: tk
# Sell Price:TK. 195 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Meiji
# Language:
# Country name:Singapore
# ...
# -----------------
#
#
# Information of Dollar Calligraphy Ink Fountain Pen Ink Bottles - 60 ml: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:22 PM
# Book Title:Dollar Calligraphy Ink Fountain Pen Ink Bottles - 60 ml
# Book Author Name:Dollar
# Book Catagory:Ink, Refill & Accessories
# Original Price: tk
# Sell Price:TK. 99 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Dollar
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Brikkho Hat Christmas Tree With 12 Inch Plastic Pot - 029: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:27 PM
# Book Title:Brikkho Hat Christmas Tree With 12 Inch Plastic Pot - 029
# Book Author Name:Brikkho Haat
# Book Catagory:Indoor Plant & Tub
# Original Price:TK. 465 tk
# Sell Price:TK. 442 tk
# Discount Rate:You Save TK. 23 (5%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Brikkho Haat
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Pentel M.pencil Twist-erase Gt 0.5mm Red Barrel - QE205B: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:31 PM
# Book Title:Pentel M.pencil Twist-erase Gt 0.5mm Red Barrel - QE205B
# Book Author Name:Pentel
# Book Catagory:Mechanical pencil
# Original Price: tk
# Sell Price:TK. 190 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Pentel
# Language:
# Country name:Japan
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Bondhubondhu Metal Notebook - NB-M-VC-C-86-002: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:35 PM
# Book Title:Bondhubondhu Metal Notebook - NB-M-VC-C-86-002
# Book Author Name:Jothashilpa
# Book Catagory:Diary and Notebook
# Original Price: tk
# Sell Price:TK. 680 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Jothashilpa
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Horse Color Glue 45CC (12 Pcs Set) - H-20: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:39 PM
# Book Title:Horse Color Glue 45CC (12 Pcs Set) - H-20
# Book Author Name:Horse
# Book Catagory:Adhesive, Gum and Glue stick
# Original Price: tk
# Sell Price:TK. 420 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Horse
# Language:
# Country name:Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Tolsen Glue Machine With 2pcs Glue Stick - 79105: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:43 PM
# Book Title:Tolsen Glue Machine With 2pcs Glue Stick - 79105
# Book Author Name:Tolsen Tools and More
# Book Catagory:Glue Gun
# Original Price:TK. 527 tk
# Sell Price:TK. 474 tk
# Discount Rate:You Save TK. 53 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Tolsen Tools and More
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of M AND G PVP GLUE STICK 25g 1 Pc - ASG97179: 164
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:48 PM
# Book Title:M AND G PVP GLUE STICK 25g 1 Pc - ASG97179
# Book Author Name:M&G
# Book Catagory:Adhesive, Gum and Glue stick
# Original Price: tk
# Sell Price:TK. 100 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:M&G
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
#
#
# ---------------data is loaded of 164---------
#
#
# ---------------data is loading from 165---------
#
#
# Information of M AND G PVP GLUE STICK 25g 1 Pc - ASG97179: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:54 PM
# Book Title:M AND G PVP GLUE STICK 25g 1 Pc - ASG97179
# Book Author Name:M&G
# Book Catagory:Adhesive, Gum and Glue stick
# Original Price: tk
# Sell Price:TK. 100 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:M&G
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Satin Acrylic Paint - 75ml, 6 Shades: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:04:59 PM
# Book Title:Mont Marte Satin Acrylic Paint - 75ml, 6 Shades
# Book Author Name:Mont Marte
# Book Catagory:Artist Inks & Paints
# Original Price: tk
# Sell Price:TK. 850 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Fancy Cute Pencil Case for Kids Any, Color Any Design-1pc: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:03 PM
# Book Title:Fancy Cute Pencil Case for Kids Any, Color Any Design-1pc
# Book Author Name:Non-Brand
# Book Catagory:Pencil box
# Original Price: tk
# Sell Price:TK. 160 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Fancy Cute Pencil Case for Kids Any, Color Any Design-1pc: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:07 PM
# Book Title:Fancy Cute Pencil Case for Kids Any, Color Any Design-1pc
# Book Author Name:Non-Brand
# Book Catagory:Pencil box
# Original Price: tk
# Sell Price:TK. 160 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Acrylic Medium Matte Premium - 135 ml: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:11 PM
# Book Title:Mont Marte Acrylic Medium Matte Premium - 135 ml
# Book Author Name:Mont Marte
# Book Catagory:Artist Inks & Paints
# Original Price: tk
# Sell Price:TK. 300 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Keep Smiling, 12 pieces, 6ml Color-Acrylic Color: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:15 PM
# Book Title:Keep Smiling, 12 pieces, 6ml Color-Acrylic Color
# Book Author Name:Keep Smiling
# Book Catagory:Artist Inks & Paints
# Original Price: tk
# Sell Price:TK. 160 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Keep Smiling
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Himi Gouache Paint Set 12ml 18 Colors: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:18 PM
# Book Title:Himi Gouache Paint Set 12ml 18 Colors
# Book Author Name:Himi Miya
# Book Catagory:Artist Inks & Paints
# Original Price: tk
# Sell Price:TK. 924 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Himi Miya
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Drools Cat Food Real Chicken Complete Nutrition - 7 Kg: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:22 PM
# Book Title:Drools Cat Food Real Chicken Complete Nutrition - 7 Kg
# Book Author Name:Drools
# Book Catagory:Cat Dry Food
# Original Price:TK. 3,622 tk
# Sell Price:TK. 2,898 tk
# Discount Rate:You Save TK. 724 (20%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Drools
# Language:
# Country name:India
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mont Marte Dimension Acrylic Paint 250ml Pot - Violet - PMDA2517: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:26 PM
# Book Title:Mont Marte Dimension Acrylic Paint 250ml Pot - Violet - PMDA2517
# Book Author Name:Mont Marte
# Book Catagory:Artist Inks & Paints
# Original Price: tk
# Sell Price:TK. 199 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mont Marte
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Liqui Moly Coolant Ready Mix RAF 12 Plus RED - 1 Litre: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:29 PM
# Book Title:Liqui Moly Coolant Ready Mix RAF 12 Plus RED - 1 Litre
# Book Author Name:LIQUI MOLY
# Book Catagory:Engine coolant
# Original Price: tk
# Sell Price:TK. 600 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:LIQUI MOLY
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Naomi Seed Ridge Gourd Green sweet - 5 gm: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:33 PM
# Book Title:Naomi Seed Ridge Gourd Green sweet - 5 gm
# Book Author Name:Naomi Seed
# Book Catagory:Plants, Seeds & Trees
# Original Price:TK. 150 tk
# Sell Price:TK. 92 tk
# Discount Rate:You Save TK. 58 (39%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Naomi Seed
# Language:
# Country name:Product by Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Naomi Seed F-1-Hybrid Bitter Gourd 5 gram - SERA-2: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:36 PM
# Book Title:Naomi Seed F-1-Hybrid Bitter Gourd 5 gram - SERA-2
# Book Author Name:Naomi Seed
# Book Catagory:Plants, Seeds & Trees
# Original Price:TK. 200 tk
# Sell Price:TK. 132 tk
# Discount Rate:You Save TK. 68 (34%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Naomi Seed
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of D-Nee Baby Fabric Softener Pouch (Green) - 600 ml - 223-0098: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:40 PM
# Book Title:D-Nee Baby Fabric Softener Pouch (Green) - 600 ml - 223-0098
# Book Author Name:D-Nee
# Book Catagory:Talcum Powder
# Original Price: tk
# Sell Price:TK. 510 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:D-Nee
# Language:
# Country name:Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of D-Nee Baby Fabric Softener Pouch (Blue) - 600 ml - 223-0098: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:44 PM
# Book Title:D-Nee Baby Fabric Softener Pouch (Blue) - 600 ml - 223-0098
# Book Author Name:D-Nee
# Book Catagory:Talcum Powder
# Original Price: tk
# Sell Price:TK. 510 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:D-Nee
# Language:
# Country name:Thailand
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Mister Potato Crisps Sour Cream and Onion 75gm Can: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:48 PM
# Book Title:Mister Potato Crisps Sour Cream and Onion 75gm Can
# Book Author Name:Mister Potato
# Book Catagory:Chips
# Original Price: tk
# Sell Price:TK. 190 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Mister Potato
# Language:
# Country name:Malaysia
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Almarai Processed Cream Cheese 500 g Saudi Arabia: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:52 PM
# Book Title:Almarai Processed Cream Cheese 500 g Saudi Arabia
# Book Author Name:Almarai
# Book Catagory:Creamer & Sugar Bowls
# Original Price: tk
# Sell Price:TK. 1,050 tk
# Discount Rate:
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Almarai
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Ziaja Mintperfect Sensitive Teeth Relief Toothpaste 75ml: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:05:57 PM
# Book Title:Ziaja Mintperfect Sensitive Teeth Relief Toothpaste 75ml
# Book Author Name:Ziaja
# Book Catagory:Toothpaste & Powder
# Original Price:TK. 650 tk
# Sell Price:TK. 618 tk
# Discount Rate:You Save TK. 32 (5%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Ziaja
# Language:
# Country name:Poland
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Topper Elite Gold Single Glass Auto Stove NG - 805353: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:06:00 PM
# Book Title:Topper Elite Gold Single Glass Auto Stove NG - 805353
# Book Author Name:Topper
# Book Catagory:Gas Stove
# Original Price:TK. 2,375 tk
# Sell Price:TK. 2,139 tk
# Discount Rate:You Save TK. 236 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Topper
# Language:
# Country name:Bangladesh
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of FA Yoghurt Aloe Vera Bar Soap 175g Dubai: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:06:04 PM
# Book Title:FA Yoghurt Aloe Vera Bar Soap 175g Dubai
# Book Author Name:Fa Soaps
# Book Catagory:Body Soaps & Shower Gels
# Original Price:TK. 500 tk
# Sell Price:TK. 209 tk
# Discount Rate:You Save TK. 291 (58%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Fa Soaps
# Language:
# Country name:
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
#
#
# Information of Flower Printed Ice Cup Water Bottle With Straw - C009020-PU: 165
#
#
# Current Date: 2024-04-19
# Current Time: 05:06:08 PM
# Book Title:Flower Printed Ice Cup Water Bottle With Straw - C009020-PU
# Book Author Name:Non-Brand
# Book Catagory:Cups, Mugs & Saucers
# Original Price:TK. 684 tk
# Sell Price:TK. 615 tk
# Discount Rate:You Save TK. 69 (10%)
# Best seller merit:
# E-book availability:No
# E-book price:
# Total Ratings:
# Total Review:
# Ratings:
# Publication name:Non-Brand
# Language:
# Country name:China
# C:/Users/asmto/OneDrive/Desktop/rokomari web scrapping projects/rokomari_superstore_informations3.xlsx
# -----------------
